# %% [markdown]
# # Natürliche Personen mit Alleinstehendenabzug separiert
# Hans Frauchiger von der Steuerverwaltung hat mir in einem Sheets auch noch den Alleinstehendenabzug mit eingerechnet, den Personen machen dürfen, die in einzelnen Haushalten leben (oder? verifizieren nochmals mit ihm). Es hat zudem einen aktuelleren Veranlagungsstand als die Zahlen im Netz. Ich nehme deshalb diese Tabelle, obschon ich damit halt die andere Coder-Büez zu viel gemacht habe.

# %%
import pandas as pd
# %matplotlib inline

# %%
Alleinstehendenabzug = pd.read_csv('2020 Rutschi BZ CAS - Pivot.csv')
Alleinstehendenabzug
# Out:
#            Unnamed: 0                           Unnamed: 1   Unnamed: 2  \
# 0                 NaN                                  NaN          NaN
# 1                 NaN                                  NaN          NaN
# 2                 NaN                                  NaN          NaN
# 3                 NaN                                  NaN   Steuerjahr
# 4                 NaN                                  NaN         2005
# 5                 NaN                                  NaN           AS
# 6   Einkommens-Klasse                               Values           Ja
# 7                   0                     Summe von Anzahl       18,214
# 8                 NaN  Summe von Einfache Steuer Einkommen            0
# 9               20000                     Summe von Anzahl       38,886
# 10                NaN  Summe von Einfache Steuer Einkommen   14,643,907
# 11              40000                     Summe von Anzahl       61,464
# 12                NaN  Summe von Einfache Steuer Einkommen   68,400,992
# 13              60000                     Summe von Anzahl       33,607
# 14                NaN  Summe von Einfache Steuer Einkommen   65,554,401
# 15              80000                     Summe von Anzahl       11,696
# 16                NaN  Summe von Einfache Steuer Einkommen   34,589,155
# 17             100000                     Summe von Anzahl        4,280
# 18                NaN  Summe von Einfache Steuer Einkommen   17,360,976
# 19             125000                     Summe von Anzahl        1,979
# 20                NaN  Summe von Einfache Steuer Einkommen   10,449,545
# 21             150000                     Summe von Anzahl          808
# 22                NaN  Summe von Einfache Steuer Einkommen    5,482,301
# 23             175000                     Summe von Anzahl          410
# 24                NaN  Summe von Einfache Steuer Einkommen    3,405,962
# 25             200000                     Summe von Anzahl          226
# 26                NaN  Summe von Einfache Steuer Einkommen    2,224,996
# 27             250000                     Summe von Anzahl          246
# 28                NaN  Summe von Einfache Steuer Einkommen    2,960,665
# 29             300000                     Summe von Anzahl          118
# 30                NaN  Summe von Einfache Steuer Einkommen    1,799,831
# 31             400000                     Summe von Anzahl          121
# 32                NaN  Summe von Einfache Steuer Einkommen    2,355,819
# 33             500000                     Summe von Anzahl           46
# 34                NaN  Summe von Einfache Steuer Einkommen    1,203,067
# 35             750000                     Summe von Anzahl           41
# 36                NaN  Summe von Einfache Steuer Einkommen    1,455,194
# 37            1000000                     Summe von Anzahl           16
# 38                NaN  Summe von Einfache Steuer Einkommen      843,530
# 39            1000001                     Summe von Anzahl           21
# 40                NaN  Summe von Einfache Steuer Einkommen    2,650,452
# 41        Grand Total                     Summe von Anzahl      172,179
# 42                NaN  Summe von Einfache Steuer Einkommen  235,380,792
# 43                NaN                                  NaN          NaN
# 44                NaN                                  NaN          NaN
# 45                NaN                                  NaN          NaN
#
#      Unnamed: 3           Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7  \
# 0           NaN                  NaN          NaN          NaN          NaN
# 1           NaN                  NaN          NaN          NaN          NaN
# 2           NaN                  NaN          NaN          NaN          NaN
# 3    Zivilstand  Abzug Alleinstehend          NaN          NaN          NaN
# 4           NaN                  NaN         2006          NaN          NaN
# 5           NaN                   VH           AS          NaN           VH
# 6          Nein                 Nein           Ja         Nein         Nein
# 7        79,007               15,337       17,154       78,877       15,672
# 8             0                    0            0            0            0
# 9        52,602               29,243       39,289       54,249       28,356
# 10   15,396,703            7,788,340   14,715,553   15,850,601    7,471,943
# 11       49,362               47,797       60,571       50,952       46,417
# 12   55,608,538           46,085,519   67,520,304   57,610,188   44,734,141
# 13       23,388               52,687       34,137       25,453       52,259
# 14   45,772,871           92,592,893   66,609,760   49,912,451   91,912,154
# 15        6,942               37,147       11,976        7,607       37,490
# 16   20,695,861           97,573,412   35,376,549   22,650,374   98,533,249
# 17        2,316               20,003        4,511        2,664       20,552
# 18    9,469,157           72,024,072   18,255,684   10,855,443   74,023,937
# 19        1,142               12,182        2,076        1,178       12,785
# 20    6,107,450           57,679,957   10,990,992    6,291,524   60,748,031
# 21          428                5,687          874          486        5,756
# 22    2,920,819           34,737,923    5,914,488    3,315,786   35,191,253
# 23          225                2,784          419          266        2,966
# 24    1,894,046           20,911,089    3,470,723    2,219,198   22,306,796
# 25          139                1,563          240          175        1,611
# 26    1,384,941           14,017,646    2,370,457    1,736,007   14,454,525
# 27          136                1,653          279          158        1,770
# 28    1,662,118           18,318,674    3,351,735    1,914,737   19,588,536
# 29           62                  785          133           83          851
# 30      943,026           11,098,608    2,026,289    1,272,946   12,025,837
# 31           72                  733          119           69          774
# 32    1,419,284           13,614,694    2,335,084    1,370,485   14,450,639
# 33           36                  296           55           32          345
# 34      937,592            7,442,455    1,439,320      848,434    8,688,126
# 35           20                  286           34           23          303
# 36      726,709           10,038,240    1,223,414      858,814   10,621,349
# 37           15                   81           19            6           83
# 38      791,351            4,290,242    1,015,032      328,220    4,325,763
# 39            8                  120           29            9          127
# 40    1,034,312           20,407,998    3,842,773    1,126,769   16,559,668
# 41      215,900              228,384      171,915      222,287      228,117
# 42  166,764,779          528,621,763  240,458,155  178,161,976  535,635,947
# 43          NaN                  NaN          NaN          NaN          NaN
# 44          NaN                  NaN          NaN          NaN          NaN
# 45          NaN                  NaN          NaN          NaN          NaN
#
#      Unnamed: 8   Unnamed: 9  ...  Unnamed: 31  Unnamed: 32  Unnamed: 33  \
# 0           NaN          NaN  ...          NaN          NaN          NaN
# 1           NaN          NaN  ...          NaN          NaN          NaN
# 2           NaN          NaN  ...          NaN          NaN          NaN
# 3           NaN          NaN  ...          NaN          NaN          NaN
# 4          2007          NaN  ...          NaN         2015          NaN
# 5            AS          NaN  ...           VH           AS          NaN
# 6            Ja         Nein  ...         Nein           Ja         Nein
# 7        16,884       79,618  ...       16,450       18,726       80,165
# 8             0            0  ...            0            0            0
# 9        37,048       54,429  ...       26,621       35,320       58,557
# 10   13,935,610   15,789,693  ...    6,615,180   12,664,221   16,437,678
# 11       59,833       51,890  ...       39,029       57,007       57,429
# 12   66,899,931   58,968,871  ...   36,219,661   62,774,509   64,154,639
# 13       35,678       27,636  ...       47,009       42,229       39,777
# 14   69,684,380   54,184,167  ...   78,263,694   80,104,756   75,314,733
# 15       13,018        8,484  ...       39,512       16,689       13,719
# 16   38,540,732   25,198,123  ...   97,097,558   47,180,792   38,737,552
# 17        4,916        2,958  ...       24,826        6,556        5,126
# 18   19,907,803   12,059,310  ...   83,000,821   25,313,013   19,687,873
# 19        2,244        1,382  ...       15,953        3,048        2,437
# 20   11,838,791    7,353,503  ...   70,359,271   15,374,356   12,270,625
# 21          934          603  ...        7,923        1,221        1,036
# 22    6,308,640    4,118,418  ...   45,204,271    7,911,517    6,680,818
# 23          424          266  ...        4,042          606          502
# 24    3,514,293    2,216,610  ...   28,636,502    4,749,931    3,902,911
# 25          276          180  ...        2,263          333          271
# 26    2,722,998    1,777,766  ...   19,160,539    3,076,433    2,521,476
# 27          291          182  ...        2,410          356          263
# 28    3,495,383    2,204,359  ...   25,047,151    4,022,340    3,001,906
# 29          177           92  ...        1,179          227          143
# 30    2,692,313    1,406,180  ...   15,513,270    3,150,179    1,988,953
# 31          129           81  ...        1,021          174          150
# 32    2,535,188    1,633,288  ...   17,298,915    3,089,202    2,746,528
# 33           52           37  ...          480           71           52
# 34    1,361,864      961,061  ...   10,663,859    1,674,938    1,244,325
# 35           42           30  ...          415           77           48
# 36    1,516,410    1,073,123  ...   12,942,144    2,424,216    1,517,365
# 37           20            7  ...          121           18           25
# 38    1,033,981      366,358  ...    5,388,458      840,690    1,169,192
# 39           32           14  ...          170           41           24
# 40    4,633,958    1,899,404  ...   17,151,595    7,218,122    3,835,682
# 41      171,998      227,889  ...      229,424      182,699      259,724
# 42  250,622,274  191,210,234  ...  568,562,889  281,569,214  255,212,257
# 43          NaN          NaN  ...          NaN          NaN          NaN
# 44          NaN          NaN  ...          NaN          NaN          NaN
# 45          NaN          NaN  ...          NaN          NaN          NaN
#
#     Unnamed: 34  Unnamed: 35  Unnamed: 36  Unnamed: 37         Unnamed: 38  \
# 0           NaN          NaN          NaN          NaN                 NaN
# 1           NaN          NaN          NaN          NaN                 NaN
# 2           NaN          NaN          NaN          NaN                 NaN
# 3           NaN          NaN          NaN          NaN                 NaN
# 4           NaN         2016          NaN          NaN                2017
# 5            VH           AS          NaN           VH                  AS
# 6          Nein           Ja         Nein         Nein                  Ja
# 7        16,087       18,770       80,030       15,789              18,783
# 8             0            0            0            0                   0
# 9        27,170       35,406       58,936       26,314              35,486
# 10    6,790,538   12,570,711   16,501,981    6,595,779          12,611,413
# 11       38,303       56,108       57,354       37,889              56,262
# 12   35,644,158   61,946,660   64,217,830   35,326,973          62,116,850
# 13       47,089       42,536       41,864       46,403              42,824
# 14   78,532,485   80,808,448   79,182,521   77,420,327          81,369,086
# 15       39,661       17,204       14,473       40,236              17,419
# 16   97,632,027   48,712,892   40,800,982   99,036,388          49,292,443
# 17       25,478        6,815        5,301       25,638               6,902
# 18   85,188,475   26,288,096   20,258,658   85,683,157          26,657,406
# 19       16,422        3,189        2,619       17,032               3,277
# 20   72,469,677   16,072,850   13,146,133   75,147,163          16,537,725
# 21        8,312        1,322        1,078        8,445               1,317
# 22   47,433,178    8,567,117    6,942,377   48,182,566           8,485,845
# 23        4,327          618          510        4,381                 655
# 24   30,680,063    4,825,075    3,960,686   31,080,325           5,123,993
# 25        2,366          358          287        2,540                 366
# 26   20,072,549    3,318,963    2,663,181   21,486,641           3,380,946
# 27        2,444          356          277        2,510                 403
# 28   25,314,005    4,014,279    3,122,518   26,077,040           4,533,547
# 29        1,173          214          152        1,244                 191
# 30   15,435,620    2,999,122    2,127,330   16,231,768           2,629,087
# 31        1,097          156          163        1,190                 191
# 32   18,611,958    2,709,604    2,911,259   20,190,255           3,429,334
# 33          520           95           70          490                  73
# 34   11,815,728    2,273,801    1,697,113   11,034,374           1,692,381
# 35          441           77           60          457                  80
# 36   13,594,178    2,437,717    1,833,929   13,930,912           2,451,421
# 37          110           22           26          132                  27
# 38    4,739,721      964,782    1,214,100    5,840,120           1,243,944
# 39          199           46           27          205                  37
# 40   19,204,444    7,446,873    2,957,145   22,415,736           6,507,817
# 41      231,199      183,292      263,227      230,895             184,293
# 42  583,158,803  285,956,990  263,537,742  595,679,522         288,063,239
# 43          NaN          NaN          NaN          NaN                 NaN
# 44          NaN          NaN          NaN          NaN  Wachstum seit 2005
# 45          NaN          NaN          NaN          NaN                7.0%
#
#     Unnamed: 39  Unnamed: 40
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# 5           NaN           VH
# 6          Nein         Nein
# 7        79,472       15,225
# 8             0            0
# 9        59,413       26,268
# 10   16,602,815    6,622,141
# 11       58,055       37,055
# 12   64,974,840   34,540,657
# 13       42,767       46,251
# 14   80,918,370   77,207,821
# 15       14,931       40,698
# 16   42,054,247  100,296,786
# 17        5,608       25,692
# 18   21,455,908   85,926,990
# 19        2,620       17,375
# 20   13,166,084   76,765,544
# 21        1,085        8,566
# 22    6,958,090   48,945,541
# 23          525        4,503
# 24    4,075,993   31,835,918
# 25          321        2,528
# 26    2,967,058   21,369,537
# 27          266        2,631
# 28    2,920,869   27,395,087
# 29          175        1,243
# 30    2,448,502   16,334,575
# 31          157        1,186
# 32    2,802,600   19,779,718
# 33           55          545
# 34    1,366,333   12,326,645
# 35           62          468
# 36    1,818,669   14,057,328
# 37           31          154
# 38    1,350,785    6,818,491
# 39           35          212
# 40    3,930,617   23,371,065
# 41      265,578      230,600
# 42  269,811,782  603,593,842
# 43          NaN          NaN
# 44          NaN          NaN
# 45        23.0%         1.0%
#
# [46 rows x 41 columns]

# %% [markdown]
# Was chic wäre:
# 1 Tabelle Anzahl Alleinstehende ohne Abzug. Header die Jahre, Index die Einkommensklasse
# 1 Tabelle Steuerbetrag Alleinstehende ohne Abzug. Header die Jahre, Index die Einkommensklasse
# 1 Tabelle Anzahl Alleinstehende mit Abzug. Header die Jahre, Index Einkommensklasse
# 1 Tabelle Steuerbetrag Alleinstehende mit Abzug. Header die Jahre, Index Einkommensklasse
# 1 Tabelle Anzahl Ehepaare. Header die Jahre, Index Einkommensklasse
# 1 Tabelle Steuerbetrag Ehepaare. Header die Jahre, Index Einkommensklasse

# %%
#zurechtschneiden
Tabelle = Alleinstehendenabzug[7:]
Tabelle_neu = Tabelle.head(36)
Tabelle_neu
# Out:
#      Unnamed: 0                           Unnamed: 1   Unnamed: 2  \
# 7             0                     Summe von Anzahl       18,214
# 8           NaN  Summe von Einfache Steuer Einkommen            0
# 9         20000                     Summe von Anzahl       38,886
# 10          NaN  Summe von Einfache Steuer Einkommen   14,643,907
# 11        40000                     Summe von Anzahl       61,464
# 12          NaN  Summe von Einfache Steuer Einkommen   68,400,992
# 13        60000                     Summe von Anzahl       33,607
# 14          NaN  Summe von Einfache Steuer Einkommen   65,554,401
# 15        80000                     Summe von Anzahl       11,696
# 16          NaN  Summe von Einfache Steuer Einkommen   34,589,155
# 17       100000                     Summe von Anzahl        4,280
# 18          NaN  Summe von Einfache Steuer Einkommen   17,360,976
# 19       125000                     Summe von Anzahl        1,979
# 20          NaN  Summe von Einfache Steuer Einkommen   10,449,545
# 21       150000                     Summe von Anzahl          808
# 22          NaN  Summe von Einfache Steuer Einkommen    5,482,301
# 23       175000                     Summe von Anzahl          410
# 24          NaN  Summe von Einfache Steuer Einkommen    3,405,962
# 25       200000                     Summe von Anzahl          226
# 26          NaN  Summe von Einfache Steuer Einkommen    2,224,996
# 27       250000                     Summe von Anzahl          246
# 28          NaN  Summe von Einfache Steuer Einkommen    2,960,665
# 29       300000                     Summe von Anzahl          118
# 30          NaN  Summe von Einfache Steuer Einkommen    1,799,831
# 31       400000                     Summe von Anzahl          121
# 32          NaN  Summe von Einfache Steuer Einkommen    2,355,819
# 33       500000                     Summe von Anzahl           46
# 34          NaN  Summe von Einfache Steuer Einkommen    1,203,067
# 35       750000                     Summe von Anzahl           41
# 36          NaN  Summe von Einfache Steuer Einkommen    1,455,194
# 37      1000000                     Summe von Anzahl           16
# 38          NaN  Summe von Einfache Steuer Einkommen      843,530
# 39      1000001                     Summe von Anzahl           21
# 40          NaN  Summe von Einfache Steuer Einkommen    2,650,452
# 41  Grand Total                     Summe von Anzahl      172,179
# 42          NaN  Summe von Einfache Steuer Einkommen  235,380,792
#
#      Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7  \
# 7        79,007       15,337       17,154       78,877       15,672
# 8             0            0            0            0            0
# 9        52,602       29,243       39,289       54,249       28,356
# 10   15,396,703    7,788,340   14,715,553   15,850,601    7,471,943
# 11       49,362       47,797       60,571       50,952       46,417
# 12   55,608,538   46,085,519   67,520,304   57,610,188   44,734,141
# 13       23,388       52,687       34,137       25,453       52,259
# 14   45,772,871   92,592,893   66,609,760   49,912,451   91,912,154
# 15        6,942       37,147       11,976        7,607       37,490
# 16   20,695,861   97,573,412   35,376,549   22,650,374   98,533,249
# 17        2,316       20,003        4,511        2,664       20,552
# 18    9,469,157   72,024,072   18,255,684   10,855,443   74,023,937
# 19        1,142       12,182        2,076        1,178       12,785
# 20    6,107,450   57,679,957   10,990,992    6,291,524   60,748,031
# 21          428        5,687          874          486        5,756
# 22    2,920,819   34,737,923    5,914,488    3,315,786   35,191,253
# 23          225        2,784          419          266        2,966
# 24    1,894,046   20,911,089    3,470,723    2,219,198   22,306,796
# 25          139        1,563          240          175        1,611
# 26    1,384,941   14,017,646    2,370,457    1,736,007   14,454,525
# 27          136        1,653          279          158        1,770
# 28    1,662,118   18,318,674    3,351,735    1,914,737   19,588,536
# 29           62          785          133           83          851
# 30      943,026   11,098,608    2,026,289    1,272,946   12,025,837
# 31           72          733          119           69          774
# 32    1,419,284   13,614,694    2,335,084    1,370,485   14,450,639
# 33           36          296           55           32          345
# 34      937,592    7,442,455    1,439,320      848,434    8,688,126
# 35           20          286           34           23          303
# 36      726,709   10,038,240    1,223,414      858,814   10,621,349
# 37           15           81           19            6           83
# 38      791,351    4,290,242    1,015,032      328,220    4,325,763
# 39            8          120           29            9          127
# 40    1,034,312   20,407,998    3,842,773    1,126,769   16,559,668
# 41      215,900      228,384      171,915      222,287      228,117
# 42  166,764,779  528,621,763  240,458,155  178,161,976  535,635,947
#
#      Unnamed: 8   Unnamed: 9  ...  Unnamed: 31  Unnamed: 32  Unnamed: 33  \
# 7        16,884       79,618  ...       16,450       18,726       80,165
# 8             0            0  ...            0            0            0
# 9        37,048       54,429  ...       26,621       35,320       58,557
# 10   13,935,610   15,789,693  ...    6,615,180   12,664,221   16,437,678
# 11       59,833       51,890  ...       39,029       57,007       57,429
# 12   66,899,931   58,968,871  ...   36,219,661   62,774,509   64,154,639
# 13       35,678       27,636  ...       47,009       42,229       39,777
# 14   69,684,380   54,184,167  ...   78,263,694   80,104,756   75,314,733
# 15       13,018        8,484  ...       39,512       16,689       13,719
# 16   38,540,732   25,198,123  ...   97,097,558   47,180,792   38,737,552
# 17        4,916        2,958  ...       24,826        6,556        5,126
# 18   19,907,803   12,059,310  ...   83,000,821   25,313,013   19,687,873
# 19        2,244        1,382  ...       15,953        3,048        2,437
# 20   11,838,791    7,353,503  ...   70,359,271   15,374,356   12,270,625
# 21          934          603  ...        7,923        1,221        1,036
# 22    6,308,640    4,118,418  ...   45,204,271    7,911,517    6,680,818
# 23          424          266  ...        4,042          606          502
# 24    3,514,293    2,216,610  ...   28,636,502    4,749,931    3,902,911
# 25          276          180  ...        2,263          333          271
# 26    2,722,998    1,777,766  ...   19,160,539    3,076,433    2,521,476
# 27          291          182  ...        2,410          356          263
# 28    3,495,383    2,204,359  ...   25,047,151    4,022,340    3,001,906
# 29          177           92  ...        1,179          227          143
# 30    2,692,313    1,406,180  ...   15,513,270    3,150,179    1,988,953
# 31          129           81  ...        1,021          174          150
# 32    2,535,188    1,633,288  ...   17,298,915    3,089,202    2,746,528
# 33           52           37  ...          480           71           52
# 34    1,361,864      961,061  ...   10,663,859    1,674,938    1,244,325
# 35           42           30  ...          415           77           48
# 36    1,516,410    1,073,123  ...   12,942,144    2,424,216    1,517,365
# 37           20            7  ...          121           18           25
# 38    1,033,981      366,358  ...    5,388,458      840,690    1,169,192
# 39           32           14  ...          170           41           24
# 40    4,633,958    1,899,404  ...   17,151,595    7,218,122    3,835,682
# 41      171,998      227,889  ...      229,424      182,699      259,724
# 42  250,622,274  191,210,234  ...  568,562,889  281,569,214  255,212,257
#
#     Unnamed: 34  Unnamed: 35  Unnamed: 36  Unnamed: 37  Unnamed: 38  \
# 7        16,087       18,770       80,030       15,789       18,783
# 8             0            0            0            0            0
# 9        27,170       35,406       58,936       26,314       35,486
# 10    6,790,538   12,570,711   16,501,981    6,595,779   12,611,413
# 11       38,303       56,108       57,354       37,889       56,262
# 12   35,644,158   61,946,660   64,217,830   35,326,973   62,116,850
# 13       47,089       42,536       41,864       46,403       42,824
# 14   78,532,485   80,808,448   79,182,521   77,420,327   81,369,086
# 15       39,661       17,204       14,473       40,236       17,419
# 16   97,632,027   48,712,892   40,800,982   99,036,388   49,292,443
# 17       25,478        6,815        5,301       25,638        6,902
# 18   85,188,475   26,288,096   20,258,658   85,683,157   26,657,406
# 19       16,422        3,189        2,619       17,032        3,277
# 20   72,469,677   16,072,850   13,146,133   75,147,163   16,537,725
# 21        8,312        1,322        1,078        8,445        1,317
# 22   47,433,178    8,567,117    6,942,377   48,182,566    8,485,845
# 23        4,327          618          510        4,381          655
# 24   30,680,063    4,825,075    3,960,686   31,080,325    5,123,993
# 25        2,366          358          287        2,540          366
# 26   20,072,549    3,318,963    2,663,181   21,486,641    3,380,946
# 27        2,444          356          277        2,510          403
# 28   25,314,005    4,014,279    3,122,518   26,077,040    4,533,547
# 29        1,173          214          152        1,244          191
# 30   15,435,620    2,999,122    2,127,330   16,231,768    2,629,087
# 31        1,097          156          163        1,190          191
# 32   18,611,958    2,709,604    2,911,259   20,190,255    3,429,334
# 33          520           95           70          490           73
# 34   11,815,728    2,273,801    1,697,113   11,034,374    1,692,381
# 35          441           77           60          457           80
# 36   13,594,178    2,437,717    1,833,929   13,930,912    2,451,421
# 37          110           22           26          132           27
# 38    4,739,721      964,782    1,214,100    5,840,120    1,243,944
# 39          199           46           27          205           37
# 40   19,204,444    7,446,873    2,957,145   22,415,736    6,507,817
# 41      231,199      183,292      263,227      230,895      184,293
# 42  583,158,803  285,956,990  263,537,742  595,679,522  288,063,239
#
#     Unnamed: 39  Unnamed: 40
# 7        79,472       15,225
# 8             0            0
# 9        59,413       26,268
# 10   16,602,815    6,622,141
# 11       58,055       37,055
# 12   64,974,840   34,540,657
# 13       42,767       46,251
# 14   80,918,370   77,207,821
# 15       14,931       40,698
# 16   42,054,247  100,296,786
# 17        5,608       25,692
# 18   21,455,908   85,926,990
# 19        2,620       17,375
# 20   13,166,084   76,765,544
# 21        1,085        8,566
# 22    6,958,090   48,945,541
# 23          525        4,503
# 24    4,075,993   31,835,918
# 25          321        2,528
# 26    2,967,058   21,369,537
# 27          266        2,631
# 28    2,920,869   27,395,087
# 29          175        1,243
# 30    2,448,502   16,334,575
# 31          157        1,186
# 32    2,802,600   19,779,718
# 33           55          545
# 34    1,366,333   12,326,645
# 35           62          468
# 36    1,818,669   14,057,328
# 37           31          154
# 38    1,350,785    6,818,491
# 39           35          212
# 40    3,930,617   23,371,065
# 41      265,578      230,600
# 42  269,811,782  603,593,842
#
# [36 rows x 41 columns]

# %%
headers = ['Einkommensklasse', 'Werte', 'AS mit Abzug 2005', 
           'AS ohne Abzug 2005', 'Ehepaare 2005', 'AS mit Abzug 2006', 
           'AS ohne Abzug 2006', 'Ehepaare 2006', 'AS mit Abzug 2007', 
           'AS ohne Abzug 2007', 'Ehepaare 2007', 'AS mit Abzug 2008', 
           'AS ohne Abzug 2008', 'Ehepaare 2008', 'AS mit Abzug 2009', 
           'AS ohne Abzug 2009', 'Ehepaare 2009', 'AS mit Abzug 2010', 
           'AS ohne Abzug 2010', 'Ehepaare 2010', 'AS mit Abzug 2011', 
           'AS ohne Abzug 2011', 'Ehepaare 2011', 'AS mit Abzug 2012', 
           'AS ohne Abzug 2012', 'Ehepaare 2012', 'AS mit Abzug 2013', 
           'AS ohne Abzug 2013', 'Ehepaare 2013', 'AS mit Abzug 2014', 
           'AS ohne Abzug 2014', 'Ehepaare 2014', 'AS mit Abzug 2015', 
           'AS ohne Abzug 2015', 'Ehepaare 2015', 'AS mit Abzug 2016', 
           'AS ohne Abzug 2016', 'Ehepaare 2016', 'AS mit Abzug 2017', 
           'AS ohne Abzug 2017', 'Ehepaare 2017', ]
Tabelle_neu.columns = headers
Tabelle_neu.head(3)
# Out:
#   Einkommensklasse                                Werte AS mit Abzug 2005  \
# 7                0                     Summe von Anzahl            18,214
# 8              NaN  Summe von Einfache Steuer Einkommen                 0
# 9            20000                     Summe von Anzahl            38,886
#
#   AS ohne Abzug 2005 Ehepaare 2005 AS mit Abzug 2006 AS ohne Abzug 2006  \
# 7             79,007        15,337            17,154             78,877
# 8                  0             0                 0                  0
# 9             52,602        29,243            39,289             54,249
#
#   Ehepaare 2006 AS mit Abzug 2007 AS ohne Abzug 2007  ... Ehepaare 2014  \
# 7        15,672            16,884             79,618  ...        16,450
# 8             0                 0                  0  ...             0
# 9        28,356            37,048             54,429  ...        26,621
#
#   AS mit Abzug 2015 AS ohne Abzug 2015 Ehepaare 2015 AS mit Abzug 2016  \
# 7            18,726             80,165        16,087            18,770
# 8                 0                  0             0                 0
# 9            35,320             58,557        27,170            35,406
#
#   AS ohne Abzug 2016 Ehepaare 2016 AS mit Abzug 2017 AS ohne Abzug 2017  \
# 7             80,030        15,789            18,783             79,472
# 8                  0             0                 0                  0
# 9             58,936        26,314            35,486             59,413
#
#   Ehepaare 2017
# 7        15,225
# 8             0
# 9        26,268
#
# [3 rows x 41 columns]

# %%
#überflüssiges raus, erst ab 2007
del Tabelle_neu['AS mit Abzug 2005']
del Tabelle_neu['AS ohne Abzug 2005']
del Tabelle_neu['Ehepaare 2005']
del Tabelle_neu['AS mit Abzug 2006']
del Tabelle_neu['AS ohne Abzug 2006']
del Tabelle_neu['Ehepaare 2006']

# %%
# kippen, um die Chose nach Einkommensklasse zu definieren
# Tabelle kippen, um die Einkommensklasse gut anzugeben
Tabelle_gekippt = Tabelle_neu.T
Tabelle_gekippt.head(3)
# Out:
#                                  7                                    8   \
# Einkommensklasse                  0                                  NaN
# Werte              Summe von Anzahl  Summe von Einfache Steuer Einkommen
# AS mit Abzug 2007            16,884                                    0
#
#                                  9                                    10  \
# Einkommensklasse              20000                                  NaN
# Werte              Summe von Anzahl  Summe von Einfache Steuer Einkommen
# AS mit Abzug 2007            37,048                           13,935,610
#
#                                  11                                   12  \
# Einkommensklasse              40000                                  NaN
# Werte              Summe von Anzahl  Summe von Einfache Steuer Einkommen
# AS mit Abzug 2007            59,833                           66,899,931
#
#                                  13                                   14  \
# Einkommensklasse              60000                                  NaN
# Werte              Summe von Anzahl  Summe von Einfache Steuer Einkommen
# AS mit Abzug 2007            35,678                           69,684,380
#
#                                  15                                   16  ...  \
# Einkommensklasse              80000                                  NaN  ...
# Werte              Summe von Anzahl  Summe von Einfache Steuer Einkommen  ...
# AS mit Abzug 2007            13,018                           38,540,732  ...
#
#                                  33                                   34  \
# Einkommensklasse             500000                                  NaN
# Werte              Summe von Anzahl  Summe von Einfache Steuer Einkommen
# AS mit Abzug 2007                52                            1,361,864
#
#                                  35                                   36  \
# Einkommensklasse             750000                                  NaN
# Werte              Summe von Anzahl  Summe von Einfache Steuer Einkommen
# AS mit Abzug 2007                42                            1,516,410
#
#                                  37                                   38  \
# Einkommensklasse            1000000                                  NaN
# Werte              Summe von Anzahl  Summe von Einfache Steuer Einkommen
# AS mit Abzug 2007                20                            1,033,981
#
#                                  39                                   40  \
# Einkommensklasse            1000001                                  NaN
# Werte              Summe von Anzahl  Summe von Einfache Steuer Einkommen
# AS mit Abzug 2007                32                            4,633,958
#
#                                  41                                   42
# Einkommensklasse        Grand Total                                  NaN
# Werte              Summe von Anzahl  Summe von Einfache Steuer Einkommen
# AS mit Abzug 2007           171,998                          250,622,274
#
# [3 rows x 36 columns]

# %%
# Headers setzen. EK=Einkommensklasse. Anzahl=Anzahl Steuerzahler dieser Art. Steuerertrag=Summe des Steuerertrags dieser Leute
headers = ['Anzahl EK 0', 'Steuerertrag EK 0', 'Anzahl EK 20000', 'Steuerertrag EK 20000', 
           'Anzahl EK 40000', 'Steuerertrag EK 40000', 'Anzahl EK 60000', 'Steuerertrag EK 60000',
          'Anzahl EK 80000', 'Steuerertrag EK 80000', 'Anzahl EK 100000', 'Steuerertrag EK 100000',
          'Anzahl EK 125000', 'Steuerertrag EK 125000', 'Anzahl EK 150000', 'Steuerertrag EK 150000',
          'Anzahl EK 175000', 'Steuerertrag EK 175000', 'Anzahl EK 200000', 'Steuerertrag EK 200000',
          'Anzahl EK 250000', 'Steuerertrag EK 250000', 'Anzahl EK 300000', 'Steuerertrag EK 300000',
          'Anzahl EK 400000', 'Steuerertrag EK 400000', 'Anzahl EK 500000', 'Steuerertrag EK 500000',
          'Anzahl EK 750000', 'Steuerertrag EK 750000', 'Anzahl EK 1000000', 'Steuerertrag EK 1000000',
          'Anzahl EK 1000001', 'Steuerertrag EK 1000001', 'Total Anzahl', 'Total Steuerertrag']
Tabelle_gekippt.columns = headers
Tabelle_gekippt.head(4)
# Out:
#                          Anzahl EK 0                    Steuerertrag EK 0  \
# Einkommensklasse                   0                                  NaN
# Werte               Summe von Anzahl  Summe von Einfache Steuer Einkommen
# AS mit Abzug 2007             16,884                                    0
# AS ohne Abzug 2007            79,618                                    0
#
#                      Anzahl EK 20000                Steuerertrag EK 20000  \
# Einkommensklasse               20000                                  NaN
# Werte               Summe von Anzahl  Summe von Einfache Steuer Einkommen
# AS mit Abzug 2007             37,048                           13,935,610
# AS ohne Abzug 2007            54,429                           15,789,693
#
#                      Anzahl EK 40000                Steuerertrag EK 40000  \
# Einkommensklasse               40000                                  NaN
# Werte               Summe von Anzahl  Summe von Einfache Steuer Einkommen
# AS mit Abzug 2007             59,833                           66,899,931
# AS ohne Abzug 2007            51,890                           58,968,871
#
#                      Anzahl EK 60000                Steuerertrag EK 60000  \
# Einkommensklasse               60000                                  NaN
# Werte               Summe von Anzahl  Summe von Einfache Steuer Einkommen
# AS mit Abzug 2007             35,678                           69,684,380
# AS ohne Abzug 2007            27,636                           54,184,167
#
#                      Anzahl EK 80000                Steuerertrag EK 80000  \
# Einkommensklasse               80000                                  NaN
# Werte               Summe von Anzahl  Summe von Einfache Steuer Einkommen
# AS mit Abzug 2007             13,018                           38,540,732
# AS ohne Abzug 2007             8,484                           25,198,123
#
#                     ...  Anzahl EK 500000  \
# Einkommensklasse    ...            500000
# Werte               ...  Summe von Anzahl
# AS mit Abzug 2007   ...                52
# AS ohne Abzug 2007  ...                37
#
#                                  Steuerertrag EK 500000  Anzahl EK 750000  \
# Einkommensklasse                                    NaN            750000
# Werte               Summe von Einfache Steuer Einkommen  Summe von Anzahl
# AS mit Abzug 2007                             1,361,864                42
# AS ohne Abzug 2007                              961,061                30
#
#                                  Steuerertrag EK 750000 Anzahl EK 1000000  \
# Einkommensklasse                                    NaN           1000000
# Werte               Summe von Einfache Steuer Einkommen  Summe von Anzahl
# AS mit Abzug 2007                             1,516,410                20
# AS ohne Abzug 2007                            1,073,123                 7
#
#                                 Steuerertrag EK 1000000 Anzahl EK 1000001  \
# Einkommensklasse                                    NaN           1000001
# Werte               Summe von Einfache Steuer Einkommen  Summe von Anzahl
# AS mit Abzug 2007                             1,033,981                32
# AS ohne Abzug 2007                              366,358                14
#
#                                 Steuerertrag EK 1000001      Total Anzahl  \
# Einkommensklasse                                    NaN       Grand Total
# Werte               Summe von Einfache Steuer Einkommen  Summe von Anzahl
# AS mit Abzug 2007                             4,633,958           171,998
# AS ohne Abzug 2007                            1,899,404           227,889
#
#                                      Total Steuerertrag
# Einkommensklasse                                    NaN
# Werte               Summe von Einfache Steuer Einkommen
# AS mit Abzug 2007                           250,622,274
# AS ohne Abzug 2007                          191,210,234
#
# [4 rows x 36 columns]

# %%
Tabelle_gekippt_fertig = Tabelle_gekippt[2:]
Tabelle_gekippt_fertig
# Out:
#                    Anzahl EK 0 Steuerertrag EK 0 Anzahl EK 20000  \
# AS mit Abzug 2007       16,884                 0          37,048
# AS ohne Abzug 2007      79,618                 0          54,429
# Ehepaare 2007           16,085                 0          26,478
# AS mit Abzug 2008       15,880                 0          35,034
# AS ohne Abzug 2008      79,516                 0          55,384
# Ehepaare 2008           16,070                 0          25,360
# AS mit Abzug 2009       16,153                 0          34,401
# AS ohne Abzug 2009      81,956                 0          55,638
# Ehepaare 2009           16,596                 0          27,022
# AS mit Abzug 2010       16,430                 0          34,348
# AS ohne Abzug 2010      82,412                 0          56,760
# Ehepaare 2010           16,750                 0          26,735
# AS mit Abzug 2011       16,498                 0          34,160
# AS ohne Abzug 2011      82,856                 0          58,298
# Ehepaare 2011           16,706                 0          27,187
# AS mit Abzug 2012       16,180                 0          33,616
# AS ohne Abzug 2012      83,501                 0          59,739
# Ehepaare 2012           16,678                 0          27,536
# AS mit Abzug 2013       16,473                 0          33,498
# AS ohne Abzug 2013      83,389                 0          60,592
# Ehepaare 2013           16,819                 0          27,797
# AS mit Abzug 2014       18,885                 0          35,253
# AS ohne Abzug 2014      80,416                 0          57,244
# Ehepaare 2014           16,450                 0          26,621
# AS mit Abzug 2015       18,726                 0          35,320
# AS ohne Abzug 2015      80,165                 0          58,557
# Ehepaare 2015           16,087                 0          27,170
# AS mit Abzug 2016       18,770                 0          35,406
# AS ohne Abzug 2016      80,030                 0          58,936
# Ehepaare 2016           15,789                 0          26,314
# AS mit Abzug 2017       18,783                 0          35,486
# AS ohne Abzug 2017      79,472                 0          59,413
# Ehepaare 2017           15,225                 0          26,268
#
#                    Steuerertrag EK 20000 Anzahl EK 40000  \
# AS mit Abzug 2007             13,935,610          59,833
# AS ohne Abzug 2007            15,789,693          51,890
# Ehepaare 2007                  6,929,582          44,383
# AS mit Abzug 2008             13,199,991          58,048
# AS ohne Abzug 2008            15,960,604          53,855
# Ehepaare 2008                  6,558,300          42,442
# AS mit Abzug 2009             12,928,562          56,633
# AS ohne Abzug 2009            15,952,132          55,223
# Ehepaare 2009                  6,811,394          43,087
# AS mit Abzug 2010             12,827,383          56,153
# AS ohne Abzug 2010            16,326,625          56,456
# Ehepaare 2010                  6,741,476          42,113
# AS mit Abzug 2011             12,599,562          55,496
# AS ohne Abzug 2011            16,686,766          57,321
# Ehepaare 2011                  6,840,268          41,662
# AS mit Abzug 2012             12,243,949          53,928
# AS ohne Abzug 2012            16,981,305          59,234
# Ehepaare 2012                  6,871,133          40,969
# AS mit Abzug 2013             12,100,308          53,443
# AS ohne Abzug 2013            17,149,742          60,511
# Ehepaare 2013                  6,893,847          40,613
# AS mit Abzug 2014             12,706,981          57,088
# AS ohne Abzug 2014            16,018,509          56,129
# Ehepaare 2014                  6,615,180          39,029
# AS mit Abzug 2015             12,664,221          57,007
# AS ohne Abzug 2015            16,437,678          57,429
# Ehepaare 2015                  6,790,538          38,303
# AS mit Abzug 2016             12,570,711          56,108
# AS ohne Abzug 2016            16,501,981          57,354
# Ehepaare 2016                  6,595,779          37,889
# AS mit Abzug 2017             12,611,413          56,262
# AS ohne Abzug 2017            16,602,815          58,055
# Ehepaare 2017                  6,622,141          37,055
#
#                    Steuerertrag EK 40000 Anzahl EK 60000  \
# AS mit Abzug 2007             66,899,931          35,678
# AS ohne Abzug 2007            58,968,871          27,636
# Ehepaare 2007                 43,047,533          51,389
# AS mit Abzug 2008             65,144,334          36,397
# AS ohne Abzug 2008            61,480,266          30,629
# Ehepaare 2008                 41,273,341          50,869
# AS mit Abzug 2009             62,972,277          36,243
# AS ohne Abzug 2009            62,545,938          32,212
# Ehepaare 2009                 41,142,413          49,579
# AS mit Abzug 2010             62,559,223          36,088
# AS ohne Abzug 2010            64,038,834          33,456
# Ehepaare 2010                 40,241,560          49,113
# AS mit Abzug 2011             61,535,443          36,124
# AS ohne Abzug 2011            64,809,211          35,177
# Ehepaare 2011                 39,514,912          48,512
# AS mit Abzug 2012             58,904,539          36,461
# AS ohne Abzug 2012            65,892,922          37,287
# Ehepaare 2012                 37,945,467          48,139
# AS mit Abzug 2013             58,319,624          37,151
# AS ohne Abzug 2013            67,392,804          38,701
# Ehepaare 2013                 37,611,768          47,670
# AS mit Abzug 2014             62,813,406          41,844
# AS ohne Abzug 2014            62,595,297          38,344
# Ehepaare 2014                 36,219,661          47,009
# AS mit Abzug 2015             62,774,509          42,229
# AS ohne Abzug 2015            64,154,639          39,777
# Ehepaare 2015                 35,644,158          47,089
# AS mit Abzug 2016             61,946,660          42,536
# AS ohne Abzug 2016            64,217,830          41,864
# Ehepaare 2016                 35,326,973          46,403
# AS mit Abzug 2017             62,116,850          42,824
# AS ohne Abzug 2017            64,974,840          42,767
# Ehepaare 2017                 34,540,657          46,251
#
#                    Steuerertrag EK 60000 Anzahl EK 80000  \
# AS mit Abzug 2007             69,684,380          13,018
# AS ohne Abzug 2007            54,184,167           8,484
# Ehepaare 2007                 90,518,452          38,832
# AS mit Abzug 2008             71,284,014          13,591
# AS ohne Abzug 2008            60,114,770           9,808
# Ehepaare 2008                 89,721,922          39,517
# AS mit Abzug 2009             70,035,983          13,597
# AS ohne Abzug 2009            62,351,709          10,169
# Ehepaare 2009                 84,840,935          38,469
# AS mit Abzug 2010             69,757,006          13,850
# AS ohne Abzug 2010            64,738,982          10,818
# Ehepaare 2010                 84,057,245          38,578
# AS mit Abzug 2011             69,595,953          14,024
# AS ohne Abzug 2011            67,811,088          11,517
# Ehepaare 2011                 82,684,810          38,481
# AS mit Abzug 2012             68,809,191          14,116
# AS ohne Abzug 2012            70,548,807          12,445
# Ehepaare 2012                 79,962,544          38,608
# AS mit Abzug 2013             70,202,847          14,459
# AS ohne Abzug 2013            73,245,345          13,112
# Ehepaare 2013                 79,230,062          38,725
# AS mit Abzug 2014             79,364,809          16,227
# AS ohne Abzug 2014            72,517,860          13,048
# Ehepaare 2014                 78,263,694          39,512
# AS mit Abzug 2015             80,104,756          16,689
# AS ohne Abzug 2015            75,314,733          13,719
# Ehepaare 2015                 78,532,485          39,661
# AS mit Abzug 2016             80,808,448          17,204
# AS ohne Abzug 2016            79,182,521          14,473
# Ehepaare 2016                 77,420,327          40,236
# AS mit Abzug 2017             81,369,086          17,419
# AS ohne Abzug 2017            80,918,370          14,931
# Ehepaare 2017                 77,207,821          40,698
#
#                    Steuerertrag EK 80000  ... Anzahl EK 500000  \
# AS mit Abzug 2007             38,540,732  ...               52
# AS ohne Abzug 2007            25,198,123  ...               37
# Ehepaare 2007                102,103,647  ...              374
# AS mit Abzug 2008             40,205,875  ...               70
# AS ohne Abzug 2008            29,175,980  ...               35
# Ehepaare 2008                103,987,527  ...              375
# AS mit Abzug 2009             39,551,874  ...               62
# AS ohne Abzug 2009            29,694,343  ...               46
# Ehepaare 2009                 97,581,050  ...              396
# AS mit Abzug 2010             40,227,160  ...               61
# AS ohne Abzug 2010            31,538,585  ...               42
# Ehepaare 2010                 97,939,317  ...              439
# AS mit Abzug 2011             40,563,989  ...               57
# AS ohne Abzug 2011            33,350,596  ...               54
# Ehepaare 2011                 96,998,773  ...              397
# AS mit Abzug 2012             39,855,343  ...               71
# AS ohne Abzug 2012            35,205,632  ...               61
# Ehepaare 2012                 94,756,453  ...              436
# AS mit Abzug 2013             40,779,399  ...               62
# AS ohne Abzug 2013            37,093,367  ...               48
# Ehepaare 2013                 95,025,218  ...              458
# AS mit Abzug 2014             45,848,508  ...               81
# AS ohne Abzug 2014            36,796,163  ...               55
# Ehepaare 2014                 97,097,558  ...              480
# AS mit Abzug 2015             47,180,792  ...               71
# AS ohne Abzug 2015            38,737,552  ...               52
# Ehepaare 2015                 97,632,027  ...              520
# AS mit Abzug 2016             48,712,892  ...               95
# AS ohne Abzug 2016            40,800,982  ...               70
# Ehepaare 2016                 99,036,388  ...              490
# AS mit Abzug 2017             49,292,443  ...               73
# AS ohne Abzug 2017            42,054,247  ...               55
# Ehepaare 2017                100,296,786  ...              545
#
#                    Steuerertrag EK 500000 Anzahl EK 750000  \
# AS mit Abzug 2007               1,361,864               42
# AS ohne Abzug 2007                961,061               30
# Ehepaare 2007                   9,428,795              346
# AS mit Abzug 2008               1,771,714               60
# AS ohne Abzug 2008                885,163               32
# Ehepaare 2008                   9,210,296              358
# AS mit Abzug 2009               1,502,360               58
# AS ohne Abzug 2009              1,110,452               37
# Ehepaare 2009                   9,351,221              360
# AS mit Abzug 2010               1,503,120               54
# AS ohne Abzug 2010              1,022,085               55
# Ehepaare 2010                  10,325,486              373
# AS mit Abzug 2011               1,349,648               55
# AS ohne Abzug 2011              1,285,782               40
# Ehepaare 2011                   9,257,704              413
# AS mit Abzug 2012               1,627,692               52
# AS ohne Abzug 2012              1,459,929               43
# Ehepaare 2012                   9,998,724              400
# AS mit Abzug 2013               1,398,854               50
# AS ohne Abzug 2013              1,130,246               47
# Ehepaare 2013                  10,459,892              403
# AS mit Abzug 2014               1,859,631               58
# AS ohne Abzug 2014              1,327,246               54
# Ehepaare 2014                  10,663,859              415
# AS mit Abzug 2015               1,674,938               77
# AS ohne Abzug 2015              1,244,325               48
# Ehepaare 2015                  11,815,728              441
# AS mit Abzug 2016               2,273,801               77
# AS ohne Abzug 2016              1,697,113               60
# Ehepaare 2016                  11,034,374              457
# AS mit Abzug 2017               1,692,381               80
# AS ohne Abzug 2017              1,366,333               62
# Ehepaare 2017                  12,326,645              468
#
#                    Steuerertrag EK 750000 Anzahl EK 1000000  \
# AS mit Abzug 2007               1,516,410                20
# AS ohne Abzug 2007              1,073,123                 7
# Ehepaare 2007                  12,119,139               118
# AS mit Abzug 2008               1,980,275                13
# AS ohne Abzug 2008              1,114,804                11
# Ehepaare 2008                  12,174,485               106
# AS mit Abzug 2009               1,998,717                18
# AS ohne Abzug 2009              1,218,413                19
# Ehepaare 2009                  11,655,193               111
# AS mit Abzug 2010               1,681,617                17
# AS ohne Abzug 2010              1,795,061                15
# Ehepaare 2010                  11,988,716               116
# AS mit Abzug 2011               1,744,566                18
# AS ohne Abzug 2011              1,241,580                15
# Ehepaare 2011                  13,093,668               122
# AS mit Abzug 2012               1,615,328                20
# AS ohne Abzug 2012              1,296,077                20
# Ehepaare 2012                  12,308,908               129
# AS mit Abzug 2013               1,621,428                17
# AS ohne Abzug 2013              1,487,837                20
# Ehepaare 2013                  12,498,246               126
# AS mit Abzug 2014               1,815,266                19
# AS ohne Abzug 2014              1,727,391                11
# Ehepaare 2014                  12,942,144               121
# AS mit Abzug 2015               2,424,216                18
# AS ohne Abzug 2015              1,517,365                25
# Ehepaare 2015                  13,594,178               110
# AS mit Abzug 2016               2,437,717                22
# AS ohne Abzug 2016              1,833,929                26
# Ehepaare 2016                  13,930,912               132
# AS mit Abzug 2017               2,451,421                27
# AS ohne Abzug 2017              1,818,669                31
# Ehepaare 2017                  14,057,328               154
#
#                    Steuerertrag EK 1000000 Anzahl EK 1000001  \
# AS mit Abzug 2007                1,033,981                32
# AS ohne Abzug 2007                 366,358                14
# Ehepaare 2007                    6,156,746               121
# AS mit Abzug 2008                  623,541                37
# AS ohne Abzug 2008                 536,331                10
# Ehepaare 2008                    5,094,668               133
# AS mit Abzug 2009                  767,089                32
# AS ohne Abzug 2009                 841,292                13
# Ehepaare 2009                    5,068,541               159
# AS mit Abzug 2010                  818,958                38
# AS ohne Abzug 2010                 721,164                19
# Ehepaare 2010                    5,455,051               168
# AS mit Abzug 2011                  841,656                36
# AS ohne Abzug 2011                 726,643                15
# Ehepaare 2011                    5,537,626               162
# AS mit Abzug 2012                  979,637                33
# AS ohne Abzug 2012                 932,850                14
# Ehepaare 2012                    5,769,681               154
# AS mit Abzug 2013                  806,988                32
# AS ohne Abzug 2013                 907,039                25
# Ehepaare 2013                    5,617,100               147
# AS mit Abzug 2014                  863,504                40
# AS ohne Abzug 2014                 539,707                26
# Ehepaare 2014                    5,388,458               170
# AS mit Abzug 2015                  840,690                41
# AS ohne Abzug 2015               1,169,192                24
# Ehepaare 2015                    4,739,721               199
# AS mit Abzug 2016                  964,782                46
# AS ohne Abzug 2016               1,214,100                27
# Ehepaare 2016                    5,840,120               205
# AS mit Abzug 2017                1,243,944                37
# AS ohne Abzug 2017               1,350,785                35
# Ehepaare 2017                    6,818,491               212
#
#                    Steuerertrag EK 1000001 Total Anzahl Total Steuerertrag
# AS mit Abzug 2007                4,633,958      171,998        250,622,274
# AS ohne Abzug 2007               1,899,404      227,889        191,210,234
# Ehepaare 2007                   17,138,653      228,051        556,701,434
# AS mit Abzug 2008                4,700,320      169,083        254,609,035
# AS ohne Abzug 2008               1,152,893      235,895        207,484,005
# Ehepaare 2008                   15,517,114      228,104        568,280,729
# AS mit Abzug 2009                5,688,552      167,284        251,225,876
# AS ohne Abzug 2009               1,153,008      242,547        214,430,970
# Ehepaare 2009                   17,745,763      228,141        548,980,449
# AS mit Abzug 2010                6,285,700      167,364        252,510,011
# AS ohne Abzug 2010               1,917,164      247,694        224,206,080
# Ehepaare 2010                   19,883,083      228,010        558,570,638
# AS mit Abzug 2011                5,349,597      167,000        251,454,022
# AS ohne Abzug 2011               1,884,637      253,540        232,811,844
# Ehepaare 2011                   17,133,465      228,303        556,688,683
# AS mit Abzug 2012                5,811,888      165,229        247,143,291
# AS ohne Abzug 2012               1,941,207      261,112        240,871,437
# Ehepaare 2012                   16,776,545      228,824        548,793,279
# AS mit Abzug 2013                5,690,369      166,245        249,814,087
# AS ohne Abzug 2013               2,983,883      265,846        251,274,663
# Ehepaare 2013                   14,600,458      229,296        551,110,826
# AS mit Abzug 2014                7,389,175      181,359        275,827,208
# AS ohne Abzug 2014               2,807,619      254,545        243,560,304
# Ehepaare 2014                   17,151,595      229,424        568,562,889
# AS mit Abzug 2015                7,218,122      182,699        281,569,214
# AS ohne Abzug 2015               3,835,682      259,724        255,212,257
# Ehepaare 2015                   19,204,444      231,199        583,158,803
# AS mit Abzug 2016                7,446,873      183,292        285,956,990
# AS ohne Abzug 2016               2,957,145      263,227        263,537,742
# Ehepaare 2016                   22,415,736      230,895        595,679,522
# AS mit Abzug 2017                6,507,817      184,293        288,063,239
# AS ohne Abzug 2017               3,930,617      265,578        269,811,782
# Ehepaare 2017                   23,371,065      230,600        603,593,842
#
# [33 rows x 36 columns]

# %% [markdown]
# Jetzt muss ich das DF putzen. So viele Zeilen - die mag ich nicht jede einzeln durchgehen mit so einer geputzt-Definition, wie ich das zuvor gemacht habe. Auf https://stackoverflow.com/questions/38516481/trying-to-remove-commas-and-dollars-signs-with-pandas-in-python finde ich folgenden Code-Vorschlag, den ich ausprobiere:
#
#  if you want to operate on multiple columns, put them in a list like so:
#
# cols = ['col1', 'col2', ..., 'colN']
#
# pass them to df.replace(), specifying each char and it's replacement:
#
# df[cols] = df[cols].replace({'\$': '', ',': ''}, regex=True)

# %%
cols = ['Anzahl EK 0', 'Steuerertrag EK 0', 'Anzahl EK 20000', 'Steuerertrag EK 20000', 
           'Anzahl EK 40000', 'Steuerertrag EK 40000', 'Anzahl EK 60000', 'Steuerertrag EK 60000',
          'Anzahl EK 80000', 'Steuerertrag EK 80000', 'Anzahl EK 100000', 'Steuerertrag EK 100000',
          'Anzahl EK 125000', 'Steuerertrag EK 125000', 'Anzahl EK 150000', 'Steuerertrag EK 150000',
          'Anzahl EK 175000', 'Steuerertrag EK 175000', 'Anzahl EK 200000', 'Steuerertrag EK 200000',
          'Anzahl EK 250000', 'Steuerertrag EK 250000', 'Anzahl EK 300000', 'Steuerertrag EK 300000',
          'Anzahl EK 400000', 'Steuerertrag EK 400000', 'Anzahl EK 500000', 'Steuerertrag EK 500000',
          'Anzahl EK 750000', 'Steuerertrag EK 750000', 'Anzahl EK 1000000', 'Steuerertrag EK 1000000',
          'Anzahl EK 1000001', 'Steuerertrag EK 1000001', 'Total Anzahl', 'Total Steuerertrag',]

Tabelle_gekippt_fertig[cols] = Tabelle_gekippt_fertig[cols].replace({' ': '', ',':'', '\n':''}, regex = True)

# %%
Tabelle_gekippt_fertig.head(3)
# Out:
#                    Anzahl EK 0 Steuerertrag EK 0 Anzahl EK 20000  \
# AS mit Abzug 2007        16884                 0           37048
# AS ohne Abzug 2007       79618                 0           54429
# Ehepaare 2007            16085                 0           26478
#
#                    Steuerertrag EK 20000 Anzahl EK 40000  \
# AS mit Abzug 2007               13935610           59833
# AS ohne Abzug 2007              15789693           51890
# Ehepaare 2007                    6929582           44383
#
#                    Steuerertrag EK 40000 Anzahl EK 60000  \
# AS mit Abzug 2007               66899931           35678
# AS ohne Abzug 2007              58968871           27636
# Ehepaare 2007                   43047533           51389
#
#                    Steuerertrag EK 60000 Anzahl EK 80000  \
# AS mit Abzug 2007               69684380           13018
# AS ohne Abzug 2007              54184167            8484
# Ehepaare 2007                   90518452           38832
#
#                    Steuerertrag EK 80000  ... Anzahl EK 500000  \
# AS mit Abzug 2007               38540732  ...               52
# AS ohne Abzug 2007              25198123  ...               37
# Ehepaare 2007                  102103647  ...              374
#
#                    Steuerertrag EK 500000 Anzahl EK 750000  \
# AS mit Abzug 2007                 1361864               42
# AS ohne Abzug 2007                 961061               30
# Ehepaare 2007                     9428795              346
#
#                    Steuerertrag EK 750000 Anzahl EK 1000000  \
# AS mit Abzug 2007                 1516410                20
# AS ohne Abzug 2007                1073123                 7
# Ehepaare 2007                    12119139               118
#
#                    Steuerertrag EK 1000000 Anzahl EK 1000001  \
# AS mit Abzug 2007                  1033981                32
# AS ohne Abzug 2007                  366358                14
# Ehepaare 2007                      6156746               121
#
#                    Steuerertrag EK 1000001 Total Anzahl Total Steuerertrag
# AS mit Abzug 2007                  4633958       171998          250622274
# AS ohne Abzug 2007                 1899404       227889          191210234
# Ehepaare 2007                     17138653       228051          556701434
#
# [3 rows x 36 columns]

# %%
Einkommen = Tabelle_gekippt_fertig.astype(int)
Einkommen = Einkommen.T
Einkommen.tail(3)
# Out:
#                          AS mit Abzug 2007  AS ohne Abzug 2007  Ehepaare 2007  \
# Steuerertrag EK 1000001            4633958             1899404       17138653
# Total Anzahl                        171998              227889         228051
# Total Steuerertrag               250622274           191210234      556701434
#
#                          AS mit Abzug 2008  AS ohne Abzug 2008  Ehepaare 2008  \
# Steuerertrag EK 1000001            4700320             1152893       15517114
# Total Anzahl                        169083              235895         228104
# Total Steuerertrag               254609035           207484005      568280729
#
#                          AS mit Abzug 2009  AS ohne Abzug 2009  Ehepaare 2009  \
# Steuerertrag EK 1000001            5688552             1153008       17745763
# Total Anzahl                        167284              242547         228141
# Total Steuerertrag               251225876           214430970      548980449
#
#                          AS mit Abzug 2010  ...  Ehepaare 2014  \
# Steuerertrag EK 1000001            6285700  ...       17151595
# Total Anzahl                        167364  ...         229424
# Total Steuerertrag               252510011  ...      568562889
#
#                          AS mit Abzug 2015  AS ohne Abzug 2015  Ehepaare 2015  \
# Steuerertrag EK 1000001            7218122             3835682       19204444
# Total Anzahl                        182699              259724         231199
# Total Steuerertrag               281569214           255212257      583158803
#
#                          AS mit Abzug 2016  AS ohne Abzug 2016  Ehepaare 2016  \
# Steuerertrag EK 1000001            7446873             2957145       22415736
# Total Anzahl                        183292              263227         230895
# Total Steuerertrag               285956990           263537742      595679522
#
#                          AS mit Abzug 2017  AS ohne Abzug 2017  Ehepaare 2017
# Steuerertrag EK 1000001            6507817             3930617       23371065
# Total Anzahl                        184293              265578         230600
# Total Steuerertrag               288063239           269811782      603593842
#
# [3 rows x 33 columns]

# %% [markdown]
# Ich lasse die Tabelle mal so stehen. Denn beim Plotten kann ich ja einzelne Spalten raus nehmen.

# %% [markdown]
# # Plotten

# %% [markdown]
# #### Meine Fragestellungen:
#
# - Gibt es markante Verschiebungen bei den Einkommensklassen und im Total zwischen 2007 und 2017? Prozentmässig?
# - Vergleich Ehepaare - Alleinstehende: Wer bezahlt mehr Steuern, wer ist reicher?
#
# - Wie haben sich die Ehepaare, Alleinstehende mit und Alleinstehende ohne Abzug entwickelt anteilsmässig? Entwicklung: 2017-2007 rechnen. (Dann evtl ausrechnen, um wie viel sich das gesteigert hat in Prozent)
#
# - Wie hohe Steuern bezahlte der durchschnittliche (oder mediane) Alleinstehende pro Jahr und wie hat sich das verändert? (Das dann mit den Ehepaaren vergleichen)
# - Wie hohe Steuern bezahlte das durchschnittliche (oder mediane) Ehepaar pro Jahr und wie hat sich das verändert? (Das dann mit den Alleinstehenden vergleichen. Aber Achtung: Ehepaare durch zwei, Alleinstehende oft dann mal zwei, weil viel Konkubinat und so)
#
# - So würde man evtl auch sehen, ab welchem Einkommen die Heiratsstrafe im Kanton Bern zum Tragen kommt, sprich: Ab welchem Einkommen jeder Einzelne höhere Steuern bezahlt, wenn er verheiratet ist.

# %% [markdown]
# #### Gibt es markante Verschiebungen bei den Einkommensklassen und im Total zwischen 2007 und 2017? Prozentmässig?
#
# #### Vergleich Ehepaare - Alleinstehende: Wer bezahlt mehr Steuern, wer ist reicher?
#
# #### Wie haben sich die Ehepaare, Alleinstehende mit und Alleinstehende ohne Abzug entwickelt anteilsmässig? Entwicklung: 2017-2007 rechnen. (Dann evtl ausrechnen, um wie viel sich das gesteigert hat in Prozent)

# %%
Einkommen['Unterschied Ehepaare 2007 zu 2017'] = Einkommen['Ehepaare 2017'] - Einkommen['Ehepaare 2007']

# %%
Einkommen['Unterschied AS mit Abzug 2007 zu 2017'] = Einkommen['AS mit Abzug 2017'] - Einkommen['AS mit Abzug 2007']

# %%
Einkommen['Unterschied AS ohne Abzug 2007 zu 2017'] = Einkommen['AS ohne Abzug 2017'] - Einkommen['AS ohne Abzug 2007']

# %%
# Index benennen, damit ich damit arbeiten kann
Einkommen.index.name = 'Index'

# %%
Einkommen.head(4)
# Out:
#                        AS mit Abzug 2007  AS ohne Abzug 2007  Ehepaare 2007  \
# Index
# Anzahl EK 0                        16884               79618          16085
# Steuerertrag EK 0                      0                   0              0
# Anzahl EK 20000                    37048               54429          26478
# Steuerertrag EK 20000           13935610            15789693        6929582
#
#                        AS mit Abzug 2008  AS ohne Abzug 2008  Ehepaare 2008  \
# Index
# Anzahl EK 0                        15880               79516          16070
# Steuerertrag EK 0                      0                   0              0
# Anzahl EK 20000                    35034               55384          25360
# Steuerertrag EK 20000           13199991            15960604        6558300
#
#                        AS mit Abzug 2009  AS ohne Abzug 2009  Ehepaare 2009  \
# Index
# Anzahl EK 0                        16153               81956          16596
# Steuerertrag EK 0                      0                   0              0
# Anzahl EK 20000                    34401               55638          27022
# Steuerertrag EK 20000           12928562            15952132        6811394
#
#                        AS mit Abzug 2010  ...  Ehepaare 2015  \
# Index                                     ...
# Anzahl EK 0                        16430  ...          16087
# Steuerertrag EK 0                      0  ...              0
# Anzahl EK 20000                    34348  ...          27170
# Steuerertrag EK 20000           12827383  ...        6790538
#
#                        AS mit Abzug 2016  AS ohne Abzug 2016  Ehepaare 2016  \
# Index
# Anzahl EK 0                        18770               80030          15789
# Steuerertrag EK 0                      0                   0              0
# Anzahl EK 20000                    35406               58936          26314
# Steuerertrag EK 20000           12570711            16501981        6595779
#
#                        AS mit Abzug 2017  AS ohne Abzug 2017  Ehepaare 2017  \
# Index
# Anzahl EK 0                        18783               79472          15225
# Steuerertrag EK 0                      0                   0              0
# Anzahl EK 20000                    35486               59413          26268
# Steuerertrag EK 20000           12611413            16602815        6622141
#
#                        Unterschied Ehepaare 2007 zu 2017  \
# Index
# Anzahl EK 0                                         -860
# Steuerertrag EK 0                                      0
# Anzahl EK 20000                                     -210
# Steuerertrag EK 20000                            -307441
#
#                        Unterschied AS mit Abzug 2007 zu 2017  \
# Index
# Anzahl EK 0                                             1899
# Steuerertrag EK 0                                          0
# Anzahl EK 20000                                        -1562
# Steuerertrag EK 20000                               -1324197
#
#                        Unterschied AS ohne Abzug 2007 zu 2017
# Index
# Anzahl EK 0                                              -146
# Steuerertrag EK 0                                           0
# Anzahl EK 20000                                          4984
# Steuerertrag EK 20000                                  813122
#
# [4 rows x 36 columns]

# %% [markdown]
# ### Ein erster Plottingversuch zeigt: Um etwas sinnvolles mit dieser Chose anstellen zu können, muss ich doch zumindest Steuerbetrag von Anzahl auseinandernehmen. Ich trenne also diese beiden Sachen.

# %%
# Mein Dataframe für die Anzahl Steuerpflichtige

Anzahl_Steuerpflichtige = Einkommen.drop(['Steuerertrag EK 0', 'Steuerertrag EK 20000', 'Steuerertrag EK 40000', 
                                          'Steuerertrag EK 60000', 'Steuerertrag EK 80000', 'Steuerertrag EK 100000',
                                          'Steuerertrag EK 125000', 'Steuerertrag EK 150000', 'Steuerertrag EK 175000', 
                                          'Steuerertrag EK 200000', 'Steuerertrag EK 250000', 'Steuerertrag EK 300000',
                                          'Steuerertrag EK 750000', 'Steuerertrag EK 1000000', 'Steuerertrag EK 400000',
                                          'Steuerertrag EK 1000001', 'Steuerertrag EK 500000', 'Total Steuerertrag'])

# %%
# Mein Dataframe für den Steuerbetrag 

Steuerbetrag = Einkommen.drop(['Anzahl EK 0', 'Anzahl EK 20000', 'Anzahl EK 40000', 'Anzahl EK 60000',
                               'Anzahl EK 80000', 'Anzahl EK 100000','Anzahl EK 125000', 'Anzahl EK 150000',
                               'Anzahl EK 175000', 'Anzahl EK 200000', 'Anzahl EK 250000', 'Anzahl EK 300000',
                               'Anzahl EK 400000', 'Anzahl EK 500000','Anzahl EK 750000', 'Anzahl EK 1000000',
                               'Anzahl EK 1000001', 'Total Anzahl'])

# %% [markdown]
# ## 1. Veränderung 2007 zu 2017 absolute Zahlen

# %% [markdown]
# ### 1a) Alleinstehende ohne Abzug

# %%
Steuerbetrag['Unterschied AS ohne Abzug 2007 zu 2017'].plot(kind='barh', title = 'Veränderung Steuerertrag Alleinstehende ohne Abzug in CHF')

# %%
Anzahl_Steuerpflichtige['Unterschied AS ohne Abzug 2007 zu 2017'].plot(kind='barh', title = 'Veränderung Anzahl Alleinstehende ohne Abzug absolute Zahlen')

# %% [markdown]
# #### Kernaussage:
# Steuerbetrag: Alleinstehende ohne Abzug bezahlten 2017 rund 7,86 Millionen Franken mehr Steuern als 2007. Die Zunahme fand vor allem in den Einkommensklassen von 60000 und 80000 Franken statt.
#
# Anzahl: 2017 gab es 37689 mehr Alleinstehende ohne Abzug als 2007. Vor allem in der Einkommensklasse 60000 gibt es eine markante Zunahme.
#
# Fazit: Mehr Steuerzahler bezahlen also auch mehr Steuern.

# %% [markdown]
# ### 1b) Alleinstehende mit Abzug

# %%
Steuerbetrag['Unterschied AS mit Abzug 2007 zu 2017'].plot(kind='barh', title = 'Veränderung Steuerertrag Alleinstehende mit Abzug in CHF')

# %%
Anzahl_Steuerpflichtige['Unterschied AS mit Abzug 2007 zu 2017'].plot(kind='barh', title = 'Veränderung Anzahl Alleinstehende mit Abzug absolute Zahlen')

# %% [markdown]
# #### Kernaussage:
# Steuerertrag: Alleinstehende mit Abzug bezahlten 2017 rund 3,74 Millionen Franken mehr als 2007. Dabei nahmen die Steuererträge aus den tiefen Einkommen bis 40000 Franken ab. Besonders stark wuchsen die Erträge aus den Einkommensklassen 60000 und 80000. Auch jene der Millionäre nahm zu.
#
# Anzahl: 2017 gab es 12295 Alleinstehende mit Abzug mehr als 2007. Es gibt weniger Alleinstehende mit Abzug in den Einkommensklassen 40000 und 20000. Zugenommen haben die Singles der EK 0 (knapp 2000 mehr). Vor allem gibt es mehr Singles in der Einkommensklasse 60000 und auch in der Einkommensklasse 80000 ist der Anstieg markant.
#
# Fazit: Auch hier scheint es mengenmässig bedingt, dass es mehr Steuereinnahmen gibt. Evtl könnte da ein Median weiterhelfen.

# %% [markdown]
# ### 1c) Ehepaare

# %%
Steuerbetrag['Unterschied Ehepaare 2007 zu 2017'].plot(kind='barh', title = 'Veränderung Steuerertrag Ehepaare in CHF')

# %%
Anzahl_Steuerpflichtige['Unterschied Ehepaare 2007 zu 2017'].plot(kind='barh', title = 'Veränderung Anzahl Ehepaare absolute Zahlen')

# %% [markdown]
# #### Kernaussage:
# Steuerertrag: Ehepaare bezahlten 2017 rund 4,69 Millionen Franken mehr Steuern als 2007. In den Einkommensklassen bis 80000 Franken gingen die Erträge zurück. Dafür wuchsen sie besonders stark in den Einkommensklassen 125000 und 150000 Franken.
#
# Anzahl: Die Anzahl Ehepaare hat von 2007 bis 2017 um bloss 2549 zugenommen. Das heisst, um 5098 Personen. Das sind immer noch massiv weniger Personen als Alleinstehende mit Abzug (plus 12295) und vor allem als Alleinstehende ohne Abzug (37689). Das liegt daran, dass vor allem die Einkommensklassen 40000 und 60000 sind zurückgegangen, aber auch die tieferen EK. Der grösste Anstieg fand in den EK 100000 und 125000 statt. Das widerspiegelt sich bei den 125000 im Steuerertrag.
#
# Fazit: Die EK 125000 hat am meisten zugenommen in Steuerbetrag, aber auch in Anzahl sind das viele. Beim Steuerbetrag bezahlt die 150000 EK-Klasse mehr als die 100000, obschon weniger zugenommen hat Anzahlmässig.

# %% [markdown]
# ## 2. Veränderung 2017 zu 2007 in Prozent

# %% [markdown]
# Gibt es prozentmässig markante Verschiebungen? Dazu berechnen, wie viel Prozent von 2017 der Unterschied 2007-2017 beträgt. Oder müsste ich 2007 nehmen (This fragen)? Das ist dann eventuell etwas vergleichbarer als die Absoluten Zahlen

# %% [markdown]
# ### 2a) Alleinstehende ohne Abzug

# %% [markdown]
# Steuerbetrag

# %%
Steuerbetrag['Prozent Unterschied AS ohne Abzug 2007 zu 2017'] = (100 / Steuerbetrag['AS ohne Abzug 2017'] * Steuerbetrag['Unterschied AS ohne Abzug 2007 zu 2017'])

# %%
Steuerbetrag['Prozent Unterschied AS ohne Abzug 2007 zu 2017'].plot(kind='barh', title = 'Veränderung Steuerertrag Alleinstehende ohne Abzug in Prozent')

# %% [markdown]
# Anzahl

# %%
Anzahl_Steuerpflichtige['Prozent Unterschied AS ohne Abzug 2007 zu 2017'] = (100 / Anzahl_Steuerpflichtige['AS ohne Abzug 2017'] * Anzahl_Steuerpflichtige['Unterschied AS ohne Abzug 2007 zu 2017'])

# %%
Anzahl_Steuerpflichtige['Prozent Unterschied AS ohne Abzug 2007 zu 2017'].plot(kind='barh', title = 'Veränderung Anzahl Alleinstehende ohne Abzug in Prozent')

# %%
Steuerbetrag.tail(3)
# Out:
#                          AS mit Abzug 2007  AS ohne Abzug 2007  Ehepaare 2007  \
# Index
# Steuerertrag EK 1000000            1033981              366358        6156746
# Steuerertrag EK 1000001            4633958             1899404       17138653
# Total Steuerertrag               250622274           191210234      556701434
#
#                          AS mit Abzug 2008  AS ohne Abzug 2008  Ehepaare 2008  \
# Index
# Steuerertrag EK 1000000             623541              536331        5094668
# Steuerertrag EK 1000001            4700320             1152893       15517114
# Total Steuerertrag               254609035           207484005      568280729
#
#                          AS mit Abzug 2009  AS ohne Abzug 2009  Ehepaare 2009  \
# Index
# Steuerertrag EK 1000000             767089              841292        5068541
# Steuerertrag EK 1000001            5688552             1153008       17745763
# Total Steuerertrag               251225876           214430970      548980449
#
#                          AS mit Abzug 2010  ...  AS mit Abzug 2016  \
# Index                                       ...
# Steuerertrag EK 1000000             818958  ...             964782
# Steuerertrag EK 1000001            6285700  ...            7446873
# Total Steuerertrag               252510011  ...          285956990
#
#                          AS ohne Abzug 2016  Ehepaare 2016  AS mit Abzug 2017  \
# Index
# Steuerertrag EK 1000000             1214100        5840120            1243944
# Steuerertrag EK 1000001             2957145       22415736            6507817
# Total Steuerertrag                263537742      595679522          288063239
#
#                          AS ohne Abzug 2017  Ehepaare 2017  \
# Index
# Steuerertrag EK 1000000             1350785        6818491
# Steuerertrag EK 1000001             3930617       23371065
# Total Steuerertrag                269811782      603593842
#
#                          Unterschied Ehepaare 2007 zu 2017  \
# Index
# Steuerertrag EK 1000000                             661745
# Steuerertrag EK 1000001                            6232412
# Total Steuerertrag                                46892408
#
#                          Unterschied AS mit Abzug 2007 zu 2017  \
# Index
# Steuerertrag EK 1000000                                 209963
# Steuerertrag EK 1000001                                1873859
# Total Steuerertrag                                    37440965
#
#                          Unterschied AS ohne Abzug 2007 zu 2017  \
# Index
# Steuerertrag EK 1000000                                  984427
# Steuerertrag EK 1000001                                 2031213
# Total Steuerertrag                                     78601548
#
#                          Prozent Unterschied AS ohne Abzug 2007 zu 2017
# Index
# Steuerertrag EK 1000000                                       72.878141
# Steuerertrag EK 1000001                                       51.676696
# Total Steuerertrag                                            29.131992
#
# [3 rows x 37 columns]

# %% [markdown]
# ### Kernaussage:
#
# Prozentual hat vor allem die EK von 100000 zugenommen, sowohl bei den Steuereinnahmen als auch bei der Anzahl. Das heisst, es gibt verhältnismässig recht viel mehr Millionäre, das sieht man auch an den Einnahmen.
#
# Insgesamt verändert sich der Steuerertrag um 29,13 Prozent. Die Anzahl hat sich aber lediglich um 14,19 Prozent gesteigert.
#
# Das heisst, diese Steuerzahler haben in den letzten zehn Jahren mehr Steuern bezahlt. Das könnte daran liegen, dass es einen verhältnismässig starken Anstieg in den hohen Einkommensklassen gibt, die entsprechend auch höhere Steuerbeträge bezahlen.

# %% [markdown]
# ### 2b) Alleinstehende mit Abzug

# %% [markdown]
# Steuerbetrag

# %%
Steuerbetrag['Prozent Unterschied AS mit Abzug 2007 zu 2017'] = (100 / Steuerbetrag['AS mit Abzug 2017'] * Steuerbetrag['Unterschied AS mit Abzug 2007 zu 2017'])

# %%
Steuerbetrag['Prozent Unterschied AS mit Abzug 2007 zu 2017'].plot(kind='barh', title = 'Veränderung Steuerertrag Alleinstehende ohne Abzug in Prozent')

# %% [markdown]
# Anzahl

# %%
Anzahl_Steuerpflichtige['Prozent Unterschied AS mit Abzug 2007 zu 2017'] = (100 / Anzahl_Steuerpflichtige['AS mit Abzug 2017'] * Anzahl_Steuerpflichtige['Unterschied AS mit Abzug 2007 zu 2017'])

# %%
Anzahl_Steuerpflichtige['Prozent Unterschied AS mit Abzug 2007 zu 2017'].plot(kind='barh', title = 'Veränderung Anzahl Alleinstehende ohne Abzug in Prozent')

# %% [markdown]
# ### Kernaussage:
#
# Prozentmässig hat die Anzahl der EK 750000 am stärksten zugelegt, was sich auch in Steuererträgen wiederspiegelt. Prozentmässig weniger Steuern bezahlte die EK 300000; sie hat auch nur leicht zugelegt in Prozent anteilsmässig.
#
# OFFENE FRAGE: Bedeutet das, dass diese weniger Steuern bezahlten? Gab es Erleichterungen in diesen 10 Jahren z.B. für Dinks, die neu sind?

# %% [markdown]
# ### 2c) Ehepaare

# %% [markdown]
# Steuerbetrag

# %%
Steuerbetrag['Prozent Unterschied Ehepaare 2007 zu 2017'] = (100 / Steuerbetrag['Ehepaare 2017'] * Steuerbetrag['Unterschied Ehepaare 2007 zu 2017'])

# %%
Steuerbetrag['Prozent Unterschied Ehepaare 2007 zu 2017'].plot(kind='barh', title = 'Veränderung Steuerertrag Ehepaare in Prozent')

# %% [markdown]
# Anzahl

# %%
Anzahl_Steuerpflichtige['Prozent Unterschied Ehepaare 2007 zu 2017'] = (100 / Anzahl_Steuerpflichtige['Ehepaare 2017'] * Anzahl_Steuerpflichtige['Unterschied Ehepaare 2007 zu 2017'])

# %%
Anzahl_Steuerpflichtige['Prozent Unterschied Ehepaare 2007 zu 2017'].plot(kind='barh', title = 'Veränderung Anzahl Ehepaare in Prozent')

# %% [markdown]
# ### Kernaussage:
#
# Auch bei den Ehepaaren haben die Besserverdienenden Anzahl- und Steuerertragsmässig prozentual zugelegt (ab 1000001 chf). Insgesamt lässt sich das Bild festhalten, dass es den Bernerinnen und Bernern einkommensmässig immer besser geht und sich das entsprechend auch niederschlägt auf die Steuern.
#
# Die einzige Kategorie, in der EK 0 prozentmässig (und wohl auch in absoluten Zahlen) zugenommen hat, sind die Alleinstehenden ohne Abzug. Sind dort die Rentner dabei, im Altersheim? Mehr Studis? Oder zeigt das ein Armutsrisiko?

# %% [markdown]
# ## Alles dann auch noch anschauen genauer auf Ausdruck mit frischem Kopf

# %% [markdown]
# ## NUR DAS TOTAL PLOTTEN

# %% [markdown]
# So. UNd jetzt will ich einfach mal nur das Total anschauen. und gucken, was das hergibt. Dann mach ich vielleicht im Total noch die Median-Sause. Aber sicher nicht mehr in den Einkommensklassen. Finito damit.

# %%
Anzahl_Steuerpflichtige.head(3)
# Out:
#                  AS mit Abzug 2007  AS ohne Abzug 2007  Ehepaare 2007  \
# Index
# Anzahl EK 0                  16884               79618          16085
# Anzahl EK 20000              37048               54429          26478
# Anzahl EK 40000              59833               51890          44383
#
#                  AS mit Abzug 2008  AS ohne Abzug 2008  Ehepaare 2008  \
# Index
# Anzahl EK 0                  15880               79516          16070
# Anzahl EK 20000              35034               55384          25360
# Anzahl EK 40000              58048               53855          42442
#
#                  AS mit Abzug 2009  AS ohne Abzug 2009  Ehepaare 2009  \
# Index
# Anzahl EK 0                  16153               81956          16596
# Anzahl EK 20000              34401               55638          27022
# Anzahl EK 40000              56633               55223          43087
#
#                  AS mit Abzug 2010  ...  Ehepaare 2016  AS mit Abzug 2017  \
# Index                               ...
# Anzahl EK 0                  16430  ...          15789              18783
# Anzahl EK 20000              34348  ...          26314              35486
# Anzahl EK 40000              56153  ...          37889              56262
#
#                  AS ohne Abzug 2017  Ehepaare 2017  \
# Index
# Anzahl EK 0                   79472          15225
# Anzahl EK 20000               59413          26268
# Anzahl EK 40000               58055          37055
#
#                  Unterschied Ehepaare 2007 zu 2017  \
# Index
# Anzahl EK 0                                   -860
# Anzahl EK 20000                               -210
# Anzahl EK 40000                              -7328
#
#                  Unterschied AS mit Abzug 2007 zu 2017  \
# Index
# Anzahl EK 0                                       1899
# Anzahl EK 20000                                  -1562
# Anzahl EK 40000                                  -3571
#
#                  Unterschied AS ohne Abzug 2007 zu 2017  \
# Index
# Anzahl EK 0                                        -146
# Anzahl EK 20000                                    4984
# Anzahl EK 40000                                    6165
#
#                  Prozent Unterschied AS ohne Abzug 2007 zu 2017  \
# Index
# Anzahl EK 0                                           -0.183713
# Anzahl EK 20000                                        8.388736
# Anzahl EK 40000                                       10.619240
#
#                  Prozent Unterschied AS mit Abzug 2007 zu 2017  \
# Index
# Anzahl EK 0                                          10.110206
# Anzahl EK 20000                                      -4.401736
# Anzahl EK 40000                                      -6.347090
#
#                  Prozent Unterschied Ehepaare 2007 zu 2017
# Index
# Anzahl EK 0                                      -5.648604
# Anzahl EK 20000                                  -0.799452
# Anzahl EK 40000                                 -19.776009
#
# [3 rows x 39 columns]

# %%
#ich drehe die Tabelle, damit ich mit der Total-Kolonne arbeiten kann
joker = Anzahl_Steuerpflichtige.T

# %%
# dataframe für Anzahl Alleinstehende mit Abzug

# %%
# Meine Dataframes für die Anzahl Steuerpflichtige

Anzahl_Alleinstehende_mit_Abzug = joker.drop(['AS ohne Abzug 2007', 'AS ohne Abzug 2008','AS ohne Abzug 2009','AS ohne Abzug 2010',
                                              'AS ohne Abzug 2011','AS ohne Abzug 2012','AS ohne Abzug 2013','AS ohne Abzug 2014',
                                              'AS ohne Abzug 2015','AS ohne Abzug 2016','AS ohne Abzug 2017',
                                              'Ehepaare 2007', 'Ehepaare 2008','Ehepaare 2009','Ehepaare 2010','Ehepaare 2011',
                                              'Ehepaare 2012','Ehepaare 2013','Ehepaare 2014','Ehepaare 2015','Ehepaare 2016','Ehepaare 2017',
                                             'Unterschied Ehepaare 2007 zu 2017', 'Unterschied AS ohne Abzug 2007 zu 2017', 
                                              'Prozent Unterschied AS ohne Abzug 2007 zu 2017', 'Prozent Unterschied AS mit Abzug 2007 zu 2017', 
                                                     'Unterschied AS mit Abzug 2007 zu 2017','Prozent Unterschied Ehepaare 2007 zu 2017'])


Anzahl_Alleinstehende_ohne_Abzug = joker.drop(['AS mit Abzug 2007', 'AS mit Abzug 2008','AS mit Abzug 2009','AS mit Abzug 2010',
                                              'AS mit Abzug 2011','AS mit Abzug 2012','AS mit Abzug 2013','AS mit Abzug 2014',
                                              'AS mit Abzug 2015','AS mit Abzug 2016','AS mit Abzug 2017',
                                              'Ehepaare 2007', 'Ehepaare 2008','Ehepaare 2009','Ehepaare 2010','Ehepaare 2011',
                                              'Ehepaare 2012','Ehepaare 2013','Ehepaare 2014','Ehepaare 2015','Ehepaare 2016','Ehepaare 2017',
                                             'Unterschied Ehepaare 2007 zu 2017', 'Unterschied AS mit Abzug 2007 zu 2017', 
                                              'Prozent Unterschied AS mit Abzug 2007 zu 2017', 'Unterschied AS ohne Abzug 2007 zu 2017', 
                                                      'Prozent Unterschied Ehepaare 2007 zu 2017','Prozent Unterschied AS ohne Abzug 2007 zu 2017'])

Anzahl_Ehepaare = joker.drop(['AS mit Abzug 2007', 'AS mit Abzug 2008','AS mit Abzug 2009','AS mit Abzug 2010',
                              'AS mit Abzug 2011','AS mit Abzug 2012','AS mit Abzug 2013','AS mit Abzug 2014',
                              'AS mit Abzug 2015','AS mit Abzug 2016','AS mit Abzug 2017','AS ohne Abzug 2007', 
                              'AS ohne Abzug 2008','AS ohne Abzug 2009','AS ohne Abzug 2010','AS ohne Abzug 2011',
                              'AS ohne Abzug 2012','AS ohne Abzug 2013','AS ohne Abzug 2014','AS ohne Abzug 2015',
                              'AS ohne Abzug 2016','AS ohne Abzug 2017', 'Unterschied AS ohne Abzug 2007 zu 2017', 
                              'Unterschied AS mit Abzug 2007 zu 2017', 'Unterschied Ehepaare 2007 zu 2017', 
                                     'Prozent Unterschied AS mit Abzug 2007 zu 2017', 
                              'Prozent Unterschied AS ohne Abzug 2007 zu 2017', 'Prozent Unterschied Ehepaare 2007 zu 2017'])

# %%
# Meine Dataframes für die Steuererträge

joker2 = Steuerbetrag.T

Steuerbetrag_Alleinstehende_mit_Abzug = joker2.drop(['AS ohne Abzug 2007', 'AS ohne Abzug 2008','AS ohne Abzug 2009','AS ohne Abzug 2010',
                                              'AS ohne Abzug 2011','AS ohne Abzug 2012','AS ohne Abzug 2013','AS ohne Abzug 2014',
                                              'AS ohne Abzug 2015','AS ohne Abzug 2016','AS ohne Abzug 2017',
                                              'Ehepaare 2007', 'Ehepaare 2008','Ehepaare 2009','Ehepaare 2010','Ehepaare 2011',
                                              'Ehepaare 2012','Ehepaare 2013','Ehepaare 2014','Ehepaare 2015','Ehepaare 2016','Ehepaare 2017',
                                             'Unterschied Ehepaare 2007 zu 2017', 'Unterschied AS ohne Abzug 2007 zu 2017', 
                                              'Prozent Unterschied AS ohne Abzug 2007 zu 2017', 'Prozent Unterschied AS mit Abzug 2007 zu 2017', 
                                                     'Unterschied AS mit Abzug 2007 zu 2017','Prozent Unterschied Ehepaare 2007 zu 2017'])

Steuerbetrag_Alleinstehende_ohne_Abzug = joker2.drop(['AS mit Abzug 2007', 'AS mit Abzug 2008','AS mit Abzug 2009','AS mit Abzug 2010',
                                              'AS mit Abzug 2011','AS mit Abzug 2012','AS mit Abzug 2013','AS mit Abzug 2014',
                                              'AS mit Abzug 2015','AS mit Abzug 2016','AS mit Abzug 2017',
                                              'Ehepaare 2007', 'Ehepaare 2008','Ehepaare 2009','Ehepaare 2010','Ehepaare 2011',
                                              'Ehepaare 2012','Ehepaare 2013','Ehepaare 2014','Ehepaare 2015','Ehepaare 2016','Ehepaare 2017',
                                             'Unterschied Ehepaare 2007 zu 2017', 'Unterschied AS mit Abzug 2007 zu 2017', 
                                              'Prozent Unterschied AS mit Abzug 2007 zu 2017', 'Unterschied AS ohne Abzug 2007 zu 2017', 
                                                      'Prozent Unterschied Ehepaare 2007 zu 2017','Prozent Unterschied AS ohne Abzug 2007 zu 2017'])

Steuerbetrag_Ehepaare = joker2.drop(['AS mit Abzug 2007', 'AS mit Abzug 2008','AS mit Abzug 2009','AS mit Abzug 2010',
                              'AS mit Abzug 2011','AS mit Abzug 2012','AS mit Abzug 2013','AS mit Abzug 2014',
                              'AS mit Abzug 2015','AS mit Abzug 2016','AS mit Abzug 2017','AS ohne Abzug 2007', 
                              'AS ohne Abzug 2008','AS ohne Abzug 2009','AS ohne Abzug 2010','AS ohne Abzug 2011',
                              'AS ohne Abzug 2012','AS ohne Abzug 2013','AS ohne Abzug 2014','AS ohne Abzug 2015',
                              'AS ohne Abzug 2016','AS ohne Abzug 2017', 'Unterschied AS ohne Abzug 2007 zu 2017', 
                              'Unterschied AS mit Abzug 2007 zu 2017', 'Unterschied Ehepaare 2007 zu 2017', 
                                     'Prozent Unterschied AS mit Abzug 2007 zu 2017', 
                              'Prozent Unterschied AS ohne Abzug 2007 zu 2017', 'Prozent Unterschied Ehepaare 2007 zu 2017'])

# %% [markdown]
# ##  Entwicklung Steuerertrag

# %%
Steuerbetrag_Alleinstehende_ohne_Abzug['Total Steuerertrag'].sort_index().plot(kind = 'barh', 
                                                                               title = 'Entwicklung Steuerertrag Alleinstehende ohne Abzug')

# Was mir nicht klar ist: die Steuererträge sind hier einfach mit 2,5 angegeben, dabei wären es z.b. 250'000'000.
# Wie klär ich das?

# %%
Steuerbetrag_Alleinstehende_mit_Abzug['Total Steuerertrag'].sort_index().plot(kind = 'barh',
                                                                             title = 'Entwicklung Steuerertrag Alleinstehende mit Abzug')

# %%
Steuerbetrag_Ehepaare['Total Steuerertrag'].sort_index().plot(kind = 'barh',
                                                             title = 'Entwicklung Steuerertrag Ehepaare')

# %% [markdown]
# ## Entwicklung Anzahl

# %%
Anzahl_Alleinstehende_ohne_Abzug['Total Anzahl'].sort_index().plot(kind = 'barh', 
                                                                   title = 'Entwicklung Anzahl Alleinstehende ohne Abzug')

# %%
Anzahl_Alleinstehende_mit_Abzug['Total Anzahl'].sort_index().plot(kind = 'barh', 
                                                                   title = 'Entwicklung Anzahl Alleinstehende mit Abzug')

# %%
Anzahl_Ehepaare['Total Anzahl'].sort_index().plot(kind = 'barh', title = 'Entwicklung Anzahl Ehepaare')

# %% [markdown]
# Okay. Das reicht für die natürlichen Personen jetzt mal. Damit diese DF vergleichbar sind, müsste ich sie irgendwie in dieselbe Grafik bringen. Wie mach ich das nur?

# %%
Anzahl_Ehepaare
# Out:
# Index          Anzahl EK 0  Anzahl EK 20000  Anzahl EK 40000  Anzahl EK 60000  \
# Ehepaare 2007      16085.0          26478.0          44383.0          51389.0
# Ehepaare 2008      16070.0          25360.0          42442.0          50869.0
# Ehepaare 2009      16596.0          27022.0          43087.0          49579.0
# Ehepaare 2010      16750.0          26735.0          42113.0          49113.0
# Ehepaare 2011      16706.0          27187.0          41662.0          48512.0
# Ehepaare 2012      16678.0          27536.0          40969.0          48139.0
# Ehepaare 2013      16819.0          27797.0          40613.0          47670.0
# Ehepaare 2014      16450.0          26621.0          39029.0          47009.0
# Ehepaare 2015      16087.0          27170.0          38303.0          47089.0
# Ehepaare 2016      15789.0          26314.0          37889.0          46403.0
# Ehepaare 2017      15225.0          26268.0          37055.0          46251.0
#
# Index          Anzahl EK 80000  Anzahl EK 100000  Anzahl EK 125000  \
# Ehepaare 2007          38832.0           21638.0           13324.0
# Ehepaare 2008          39517.0           22757.0           14187.0
# Ehepaare 2009          38469.0           22250.0           13928.0
# Ehepaare 2010          38578.0           22501.0           14417.0
# Ehepaare 2011          38481.0           22907.0           14682.0
# Ehepaare 2012          38608.0           23381.0           14896.0
# Ehepaare 2013          38725.0           23386.0           15246.0
# Ehepaare 2014          39512.0           24826.0           15953.0
# Ehepaare 2015          39661.0           25478.0           16422.0
# Ehepaare 2016          40236.0           25638.0           17032.0
# Ehepaare 2017          40698.0           25692.0           17375.0
#
# Index          Anzahl EK 150000  Anzahl EK 175000  Anzahl EK 200000  \
# Ehepaare 2007            6341.0            3214.0            1838.0
# Ehepaare 2008            6736.0            3366.0            1906.0
# Ehepaare 2009            6937.0            3507.0            1884.0
# Ehepaare 2010            7124.0            3569.0            2051.0
# Ehepaare 2011            7222.0            3611.0            2033.0
# Ehepaare 2012            7403.0            3729.0            2055.0
# Ehepaare 2013            7519.0            3859.0            2217.0
# Ehepaare 2014            7923.0            4042.0            2263.0
# Ehepaare 2015            8312.0            4327.0            2366.0
# Ehepaare 2016            8445.0            4381.0            2540.0
# Ehepaare 2017            8566.0            4503.0            2528.0
#
# Index          Anzahl EK 250000  Anzahl EK 300000  Anzahl EK 400000  \
# Ehepaare 2007            1826.0             915.0             829.0
# Ehepaare 2008            2042.0             987.0             893.0
# Ehepaare 2009            1985.0            1014.0             857.0
# Ehepaare 2010            2059.0             986.0             918.0
# Ehepaare 2011            2221.0            1027.0             958.0
# Ehepaare 2012            2269.0            1079.0             963.0
# Ehepaare 2013            2192.0            1113.0            1006.0
# Ehepaare 2014            2410.0            1179.0            1021.0
# Ehepaare 2015            2444.0            1173.0            1097.0
# Ehepaare 2016            2510.0            1244.0            1190.0
# Ehepaare 2017            2631.0            1243.0            1186.0
#
# Index          Anzahl EK 500000  Anzahl EK 750000  Anzahl EK 1000000  \
# Ehepaare 2007             374.0             346.0              118.0
# Ehepaare 2008             375.0             358.0              106.0
# Ehepaare 2009             396.0             360.0              111.0
# Ehepaare 2010             439.0             373.0              116.0
# Ehepaare 2011             397.0             413.0              122.0
# Ehepaare 2012             436.0             400.0              129.0
# Ehepaare 2013             458.0             403.0              126.0
# Ehepaare 2014             480.0             415.0              121.0
# Ehepaare 2015             520.0             441.0              110.0
# Ehepaare 2016             490.0             457.0              132.0
# Ehepaare 2017             545.0             468.0              154.0
#
# Index          Anzahl EK 1000001  Total Anzahl
# Ehepaare 2007              121.0      228051.0
# Ehepaare 2008              133.0      228104.0
# Ehepaare 2009              159.0      228141.0
# Ehepaare 2010              168.0      228010.0
# Ehepaare 2011              162.0      228303.0
# Ehepaare 2012              154.0      228824.0
# Ehepaare 2013              147.0      229296.0
# Ehepaare 2014              170.0      229424.0
# Ehepaare 2015              199.0      231199.0
# Ehepaare 2016              205.0      230895.0
# Ehepaare 2017              212.0      230600.0

# %%
#Es sieht so aus, als müsste ich die drei DF zusammentun. Dann kann ich die Totals zusammen plotten. 

#die beiden df einkommen_2007 und getrennte_kolonnen07 zusammenfügen
Anzahl_neu = pd.concat([Anzahl_Ehepaare, Anzahl_Alleinstehende_ohne_Abzug, Anzahl_Alleinstehende_mit_Abzug], axis=1)


Anzahl_neu
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.
# Index               Anzahl EK 0  Anzahl EK 20000  Anzahl EK 40000  \
# AS mit Abzug 2007           NaN              NaN              NaN
# AS mit Abzug 2008           NaN              NaN              NaN
# AS mit Abzug 2009           NaN              NaN              NaN
# AS mit Abzug 2010           NaN              NaN              NaN
# AS mit Abzug 2011           NaN              NaN              NaN
# AS mit Abzug 2012           NaN              NaN              NaN
# AS mit Abzug 2013           NaN              NaN              NaN
# AS mit Abzug 2014           NaN              NaN              NaN
# AS mit Abzug 2015           NaN              NaN              NaN
# AS mit Abzug 2016           NaN              NaN              NaN
# AS mit Abzug 2017           NaN              NaN              NaN
# AS ohne Abzug 2007          NaN              NaN              NaN
# AS ohne Abzug 2008          NaN              NaN              NaN
# AS ohne Abzug 2009          NaN              NaN              NaN
# AS ohne Abzug 2010          NaN              NaN              NaN
# AS ohne Abzug 2011          NaN              NaN              NaN
# AS ohne Abzug 2012          NaN              NaN              NaN
# AS ohne Abzug 2013          NaN              NaN              NaN
# AS ohne Abzug 2014          NaN              NaN              NaN
# AS ohne Abzug 2015          NaN              NaN              NaN
# AS ohne Abzug 2016          NaN              NaN              NaN
# AS ohne Abzug 2017          NaN              NaN              NaN
# Ehepaare 2007           16085.0          26478.0          44383.0
# Ehepaare 2008           16070.0          25360.0          42442.0
# Ehepaare 2009           16596.0          27022.0          43087.0
# Ehepaare 2010           16750.0          26735.0          42113.0
# Ehepaare 2011           16706.0          27187.0          41662.0
# Ehepaare 2012           16678.0          27536.0          40969.0
# Ehepaare 2013           16819.0          27797.0          40613.0
# Ehepaare 2014           16450.0          26621.0          39029.0
# Ehepaare 2015           16087.0          27170.0          38303.0
# Ehepaare 2016           15789.0          26314.0          37889.0
# Ehepaare 2017           15225.0          26268.0          37055.0
#
# Index               Anzahl EK 60000  Anzahl EK 80000  Anzahl EK 100000  \
# AS mit Abzug 2007               NaN              NaN               NaN
# AS mit Abzug 2008               NaN              NaN               NaN
# AS mit Abzug 2009               NaN              NaN               NaN
# AS mit Abzug 2010               NaN              NaN               NaN
# AS mit Abzug 2011               NaN              NaN               NaN
# AS mit Abzug 2012               NaN              NaN               NaN
# AS mit Abzug 2013               NaN              NaN               NaN
# AS mit Abzug 2014               NaN              NaN               NaN
# AS mit Abzug 2015               NaN              NaN               NaN
# AS mit Abzug 2016               NaN              NaN               NaN
# AS mit Abzug 2017               NaN              NaN               NaN
# AS ohne Abzug 2007              NaN              NaN               NaN
# AS ohne Abzug 2008              NaN              NaN               NaN
# AS ohne Abzug 2009              NaN              NaN               NaN
# AS ohne Abzug 2010              NaN              NaN               NaN
# AS ohne Abzug 2011              NaN              NaN               NaN
# AS ohne Abzug 2012              NaN              NaN               NaN
# AS ohne Abzug 2013              NaN              NaN               NaN
# AS ohne Abzug 2014              NaN              NaN               NaN
# AS ohne Abzug 2015              NaN              NaN               NaN
# AS ohne Abzug 2016              NaN              NaN               NaN
# AS ohne Abzug 2017              NaN              NaN               NaN
# Ehepaare 2007               51389.0          38832.0           21638.0
# Ehepaare 2008               50869.0          39517.0           22757.0
# Ehepaare 2009               49579.0          38469.0           22250.0
# Ehepaare 2010               49113.0          38578.0           22501.0
# Ehepaare 2011               48512.0          38481.0           22907.0
# Ehepaare 2012               48139.0          38608.0           23381.0
# Ehepaare 2013               47670.0          38725.0           23386.0
# Ehepaare 2014               47009.0          39512.0           24826.0
# Ehepaare 2015               47089.0          39661.0           25478.0
# Ehepaare 2016               46403.0          40236.0           25638.0
# Ehepaare 2017               46251.0          40698.0           25692.0
#
# Index               Anzahl EK 125000  Anzahl EK 150000  Anzahl EK 175000  \
# AS mit Abzug 2007                NaN               NaN               NaN
# AS mit Abzug 2008                NaN               NaN               NaN
# AS mit Abzug 2009                NaN               NaN               NaN
# AS mit Abzug 2010                NaN               NaN               NaN
# AS mit Abzug 2011                NaN               NaN               NaN
# AS mit Abzug 2012                NaN               NaN               NaN
# AS mit Abzug 2013                NaN               NaN               NaN
# AS mit Abzug 2014                NaN               NaN               NaN
# AS mit Abzug 2015                NaN               NaN               NaN
# AS mit Abzug 2016                NaN               NaN               NaN
# AS mit Abzug 2017                NaN               NaN               NaN
# AS ohne Abzug 2007               NaN               NaN               NaN
# AS ohne Abzug 2008               NaN               NaN               NaN
# AS ohne Abzug 2009               NaN               NaN               NaN
# AS ohne Abzug 2010               NaN               NaN               NaN
# AS ohne Abzug 2011               NaN               NaN               NaN
# AS ohne Abzug 2012               NaN               NaN               NaN
# AS ohne Abzug 2013               NaN               NaN               NaN
# AS ohne Abzug 2014               NaN               NaN               NaN
# AS ohne Abzug 2015               NaN               NaN               NaN
# AS ohne Abzug 2016               NaN               NaN               NaN
# AS ohne Abzug 2017               NaN               NaN               NaN
# Ehepaare 2007                13324.0            6341.0            3214.0
# Ehepaare 2008                14187.0            6736.0            3366.0
# Ehepaare 2009                13928.0            6937.0            3507.0
# Ehepaare 2010                14417.0            7124.0            3569.0
# Ehepaare 2011                14682.0            7222.0            3611.0
# Ehepaare 2012                14896.0            7403.0            3729.0
# Ehepaare 2013                15246.0            7519.0            3859.0
# Ehepaare 2014                15953.0            7923.0            4042.0
# Ehepaare 2015                16422.0            8312.0            4327.0
# Ehepaare 2016                17032.0            8445.0            4381.0
# Ehepaare 2017                17375.0            8566.0            4503.0
#
# Index               Anzahl EK 200000  ...  Anzahl EK 175000  Anzahl EK 200000  \
# AS mit Abzug 2007                NaN  ...             424.0             276.0
# AS mit Abzug 2008                NaN  ...             483.0             253.0
# AS mit Abzug 2009                NaN  ...             491.0             278.0
# AS mit Abzug 2010                NaN  ...             514.0             269.0
# AS mit Abzug 2011                NaN  ...             532.0             283.0
# AS mit Abzug 2012                NaN  ...             523.0             308.0
# AS mit Abzug 2013                NaN  ...             532.0             294.0
# AS mit Abzug 2014                NaN  ...             566.0             307.0
# AS mit Abzug 2015                NaN  ...             606.0             333.0
# AS mit Abzug 2016                NaN  ...             618.0             358.0
# AS mit Abzug 2017                NaN  ...             655.0             366.0
# AS ohne Abzug 2007               NaN  ...               NaN               NaN
# AS ohne Abzug 2008               NaN  ...               NaN               NaN
# AS ohne Abzug 2009               NaN  ...               NaN               NaN
# AS ohne Abzug 2010               NaN  ...               NaN               NaN
# AS ohne Abzug 2011               NaN  ...               NaN               NaN
# AS ohne Abzug 2012               NaN  ...               NaN               NaN
# AS ohne Abzug 2013               NaN  ...               NaN               NaN
# AS ohne Abzug 2014               NaN  ...               NaN               NaN
# AS ohne Abzug 2015               NaN  ...               NaN               NaN
# AS ohne Abzug 2016               NaN  ...               NaN               NaN
# AS ohne Abzug 2017               NaN  ...               NaN               NaN
# Ehepaare 2007                 1838.0  ...               NaN               NaN
# Ehepaare 2008                 1906.0  ...               NaN               NaN
# Ehepaare 2009                 1884.0  ...               NaN               NaN
# Ehepaare 2010                 2051.0  ...               NaN               NaN
# Ehepaare 2011                 2033.0  ...               NaN               NaN
# Ehepaare 2012                 2055.0  ...               NaN               NaN
# Ehepaare 2013                 2217.0  ...               NaN               NaN
# Ehepaare 2014                 2263.0  ...               NaN               NaN
# Ehepaare 2015                 2366.0  ...               NaN               NaN
# Ehepaare 2016                 2540.0  ...               NaN               NaN
# Ehepaare 2017                 2528.0  ...               NaN               NaN
#
# Index               Anzahl EK 250000  Anzahl EK 300000  Anzahl EK 400000  \
# AS mit Abzug 2007              291.0             177.0             129.0
# AS mit Abzug 2008              302.0             148.0             146.0
# AS mit Abzug 2009              308.0             168.0             149.0
# AS mit Abzug 2010              334.0             133.0             166.0
# AS mit Abzug 2011              324.0             166.0             167.0
# AS mit Abzug 2012              328.0             169.0             151.0
# AS mit Abzug 2013              327.0             190.0             151.0
# AS mit Abzug 2014              330.0             197.0             177.0
# AS mit Abzug 2015              356.0             227.0             174.0
# AS mit Abzug 2016              356.0             214.0             156.0
# AS mit Abzug 2017              403.0             191.0             191.0
# AS ohne Abzug 2007               NaN               NaN               NaN
# AS ohne Abzug 2008               NaN               NaN               NaN
# AS ohne Abzug 2009               NaN               NaN               NaN
# AS ohne Abzug 2010               NaN               NaN               NaN
# AS ohne Abzug 2011               NaN               NaN               NaN
# AS ohne Abzug 2012               NaN               NaN               NaN
# AS ohne Abzug 2013               NaN               NaN               NaN
# AS ohne Abzug 2014               NaN               NaN               NaN
# AS ohne Abzug 2015               NaN               NaN               NaN
# AS ohne Abzug 2016               NaN               NaN               NaN
# AS ohne Abzug 2017               NaN               NaN               NaN
# Ehepaare 2007                    NaN               NaN               NaN
# Ehepaare 2008                    NaN               NaN               NaN
# Ehepaare 2009                    NaN               NaN               NaN
# Ehepaare 2010                    NaN               NaN               NaN
# Ehepaare 2011                    NaN               NaN               NaN
# Ehepaare 2012                    NaN               NaN               NaN
# Ehepaare 2013                    NaN               NaN               NaN
# Ehepaare 2014                    NaN               NaN               NaN
# Ehepaare 2015                    NaN               NaN               NaN
# Ehepaare 2016                    NaN               NaN               NaN
# Ehepaare 2017                    NaN               NaN               NaN
#
# Index               Anzahl EK 500000  Anzahl EK 750000  Anzahl EK 1000000  \
# AS mit Abzug 2007               52.0              42.0               20.0
# AS mit Abzug 2008               70.0              60.0               13.0
# AS mit Abzug 2009               62.0              58.0               18.0
# AS mit Abzug 2010               61.0              54.0               17.0
# AS mit Abzug 2011               57.0              55.0               18.0
# AS mit Abzug 2012               71.0              52.0               20.0
# AS mit Abzug 2013               62.0              50.0               17.0
# AS mit Abzug 2014               81.0              58.0               19.0
# AS mit Abzug 2015               71.0              77.0               18.0
# AS mit Abzug 2016               95.0              77.0               22.0
# AS mit Abzug 2017               73.0              80.0               27.0
# AS ohne Abzug 2007               NaN               NaN                NaN
# AS ohne Abzug 2008               NaN               NaN                NaN
# AS ohne Abzug 2009               NaN               NaN                NaN
# AS ohne Abzug 2010               NaN               NaN                NaN
# AS ohne Abzug 2011               NaN               NaN                NaN
# AS ohne Abzug 2012               NaN               NaN                NaN
# AS ohne Abzug 2013               NaN               NaN                NaN
# AS ohne Abzug 2014               NaN               NaN                NaN
# AS ohne Abzug 2015               NaN               NaN                NaN
# AS ohne Abzug 2016               NaN               NaN                NaN
# AS ohne Abzug 2017               NaN               NaN                NaN
# Ehepaare 2007                    NaN               NaN                NaN
# Ehepaare 2008                    NaN               NaN                NaN
# Ehepaare 2009                    NaN               NaN                NaN
# Ehepaare 2010                    NaN               NaN                NaN
# Ehepaare 2011                    NaN               NaN                NaN
# Ehepaare 2012                    NaN               NaN                NaN
# Ehepaare 2013                    NaN               NaN                NaN
# Ehepaare 2014                    NaN               NaN                NaN
# Ehepaare 2015                    NaN               NaN                NaN
# Ehepaare 2016                    NaN               NaN                NaN
# Ehepaare 2017                    NaN               NaN                NaN
#
# Index               Anzahl EK 1000001  Total Anzahl
# AS mit Abzug 2007                32.0      171998.0
# AS mit Abzug 2008                37.0      169083.0
# AS mit Abzug 2009                32.0      167284.0
# AS mit Abzug 2010                38.0      167364.0
# AS mit Abzug 2011                36.0      167000.0
# AS mit Abzug 2012                33.0      165229.0
# AS mit Abzug 2013                32.0      166245.0
# AS mit Abzug 2014                40.0      181359.0
# AS mit Abzug 2015                41.0      182699.0
# AS mit Abzug 2016                46.0      183292.0
# AS mit Abzug 2017                37.0      184293.0
# AS ohne Abzug 2007                NaN           NaN
# AS ohne Abzug 2008                NaN           NaN
# AS ohne Abzug 2009                NaN           NaN
# AS ohne Abzug 2010                NaN           NaN
# AS ohne Abzug 2011                NaN           NaN
# AS ohne Abzug 2012                NaN           NaN
# AS ohne Abzug 2013                NaN           NaN
# AS ohne Abzug 2014                NaN           NaN
# AS ohne Abzug 2015                NaN           NaN
# AS ohne Abzug 2016                NaN           NaN
# AS ohne Abzug 2017                NaN           NaN
# Ehepaare 2007                     NaN           NaN
# Ehepaare 2008                     NaN           NaN
# Ehepaare 2009                     NaN           NaN
# Ehepaare 2010                     NaN           NaN
# Ehepaare 2011                     NaN           NaN
# Ehepaare 2012                     NaN           NaN
# Ehepaare 2013                     NaN           NaN
# Ehepaare 2014                     NaN           NaN
# Ehepaare 2015                     NaN           NaN
# Ehepaare 2016                     NaN           NaN
# Ehepaare 2017                     NaN           NaN
#
# [33 rows x 54 columns]

# %%
#die beiden df einkommen_2007 und getrennte_kolonnen07 zusammenfügen
Einkommen_2007_neu = pd.concat([getrennte_kolonnen07, einkommen_2007], axis=1)
Einkommen_2007_neu

### wahrscheinlich hats ein Problem, weil die drei Headers gleich sind. 
#Gut wäre, von allen Dataframes die Totals rausziehen zu können und diese wieder zusammenkleben
