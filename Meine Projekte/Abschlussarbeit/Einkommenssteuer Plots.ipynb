# %% [markdown]
# # Einkommenssteuer Plots

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Grundsätzlich schauen: Macht die Abstufung zwischen den Einkommen Sinn?

# %% [markdown]
# ## Alleinstehende

# %% [markdown]
# #### Meine Fragestellungen:
# - Gibt es markante Verschiebungen bei den Einkommensklassen und im Total zwischen 2007 und 2017? Prozentmässig?
# - Vergleich Ehepaare - Alleinstehende: Wer ist reicher?
# - Wie hohe Steuern bezahlte der durchschnittliche (oder mediane) Alleinstehende pro Jahr und wie hat sich das verändert? (Das dann mit den Ehepaaren vergleichen)
# - Hier noch das Wachstum des Alleinstehendenabzugs erwähnen, das dann zeigt: Nicht die wirklich Alleinstehenden haben gewachsen, sondern die Leute in Mehrpersonenhaushalten. Das können auch Altersheime oder WGs sein, oder aber Konkubinatspaare. Hier nur die Prozentzahl nehmen, da die Berechnungen des Kantons auf anderen Zahlen beruhen (Veranlagungsstand) als die hier vorliegenden.

# %% [markdown]
# ### 1. Anzahl

# %%
Steuerpflichtige_Alleinstehende = pd.read_csv('Steuerpflichtige Alleinstehende 2007 bis 2017')
Steuerpflichtige_Alleinstehende
# Out:
#                     Unnamed: 0  Einkommen 0 CHF  Einkommen 100-20000 CHF  \
# 0   Anzahl Alleinstehende 2007            96546                    91488
# 1   Anzahl Alleinstehende 2008            95464                    90431
# 2   Anzahl Alleinstehende 2009            98157                    90024
# 3   Anzahl Alleinstehende 2010            98843                    91013
# 4   Anzahl Alleinstehende 2011            99323                    92449
# 5   Anzahl Alleinstehende 2012            99844                    93077
# 6   Anzahl Alleinstehende 2013           100005                    93874
# 7   Anzahl Alleinstehende 2014            99385                    92256
# 8   Anzahl Alleinstehende 2015            98952                    93211
# 9   Anzahl Alleinstehende 2016            98826                    93568
# 10  Anzahl Alleinstehende 2017            98122                    94229
#
#     Einkommen 20100-40000 CHF  Einkommen 40100-60000 CHF  \
# ...

# %% [markdown]
# ### 2. Steuerbetrag

# %%
Steuerbetrag_Alleinstehende = pd.read_csv('Steuerbetrag Alleinstehende 2007 bis 2017')
Steuerbetrag_Alleinstehende
# Out:
#                                   Unnamed: 0  Einkommen 0 CHF  \
# 0   Betrag Kantonssteuer Alleinstehende 2007                0
# 1   Betrag Kantonssteuer Alleinstehende 2008                0
# 2   Betrag Kantonssteuer Alleinstehende 2009                0
# 3   Betrag Kantonssteuer Alleinstehende 2010                0
# 4   Betrag Kantonssteuer Alleinstehende 2011                0
# 5   Betrag Kantonssteuer Alleinstehende 2012                0
# 6   Betrag Kantonssteuer Alleinstehende 2013                0
# 7   Betrag Kantonssteuer Alleinstehende 2014                0
# 8   Betrag Kantonssteuer Alleinstehende 2015                0
# 9   Betrag Kantonssteuer Alleinstehende 2016                0
# 10  Betrag Kantonssteuer Alleinstehende 2017                0
#
#     Einkommen 100-20000 CHF  Einkommen 20100-40000 CHF  \
# 0                  90950139                  385187702
# 1                  86318137                  374832754
# ...

# %% [markdown]
# ## Ehepaare

# %% [markdown]
# #### Meine Fragestellungen:
# - Gibt es markante Verschiebungen bei den Einkommensklassen und im Total zwischen 2007 und 2017? Prozentmässig?
# - Vergleich Ehepaare - Alleinstehende: Wer ist reicher?
# - Wie hohe Steuern bezahlte das durchschnittliche (oder mediane) Ehepaar pro Jahr und wie hat sich das verändert? (Das dann mit den Alleinstehenden vergleichen. Aber Achtung: Ehepaare durch zwei, Alleinstehende oft dann mal zwei, weil viel Konkubinat und so)
# - So würde man evtl auch sehen, ab welchem Einkommen die Heiratsstrafe im Kanton Bern zum Tragen kommt, sprich: Ab welchem Einkommen jeder Einzelne höhere Steuern bezahlt, wenn er verheiratet ist.

# %% [markdown]
# ### 1. Anzahl

# %%
Steuerpflichtige_Ehepaare = pd.read_csv('Steuerpflichtige Ehepaare 2007 bis 2017')
Steuerpflichtige_Ehepaare
# Out:
#               Unnamed: 0  Einkommen 0 CHF  Einkommen 100-20000 CHF  \
# 0   Anzahl Ehepaare 2007            16092                    26479
# 1   Anzahl Ehepaare 2008            16064                    25347
# 2   Anzahl Ehepaare 2009            16566                    27006
# 3   Anzahl Ehepaare 2010            16727                    26648
# 4   Anzahl Ehepaare 2011            16703                    27128
# 5   Anzahl Ehepaare 2012            16877                    27277
# 6   Anzahl Ehepaare 2013            17007                    27536
# 7   Anzahl Ehepaare 2014            16631                    26423
# 8   Anzahl Ehepaare 2015            16263                    26592
# 9   Anzahl Ehepaare 2016            15981                    25772
# 10  Anzahl Ehepaare 2017            15453                    25764
#
#     Einkommen 20100-40000 CHF  Einkommen 40100-60000 CHF  \
# 0                       44385                      51389
# ...

# %% [markdown]
# ### 2. Steuerbetrag

# %%
Steuerbetrag_Ehepaare = pd.read_csv('Steuerbetrag Ehepaare 2007 bis 2017')
Steuerbetrag_Ehepaare
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-383933fb975c> in <module>
# ----> 1 Steuerbetrag_Ehepaare = pd.read_csv('Steuerbetrag Ehepaare 2007 bis 2017')
#       2 Steuerbetrag_Ehepaare
#
# NameError: name 'pd' is not defined
