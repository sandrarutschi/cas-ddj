# %% [markdown]
# # Filtern und Felder kombinieren

# %% [markdown]
# **Inhalt:** Die Nadel im Heuhaufen finden
#
# **Nötige Skills:** Erste Schritte mit Pandas
#
# **Lernziele:**
# - Einträge im Datenset finden, basierend auf Kriterien
# - Nan kennenlernen
# - Neue Datenfelder generieren
# - Plotting Level 1

# %% [markdown]
# # Das Beispiel

# %% [markdown]
# Die besten NBA-Basketball-Spieler aller Zeiten.
#
# Quelle/Beschreibung: https://stats.nba.com/alltime-leaders/
#
# Die Daten haben wir manuell kopiert und an diesem Ort hier abgelegt: `dataprojects/nba-players`

# %% [markdown]
# ## Vorbereitung

# %%
import pandas as pd

# %%
# %matplotlib inline

# %% [markdown]
# ## Datenfile laden

# %% [markdown]
# Wo ist die Datei?

# %%
path = 'dataprojects/nba-players/alltime.xlsx'

# %% [markdown]
# Für den Import von Excel-Dateien nutzen wir die Funktion `read_excel()`

# %%
df = pd.read_excel(path)

# %% [markdown]
# ## Überblick verschaffen

# %% [markdown]
# Wie immer zu Beginn, checken wir die Struktur und Länge des Datensets ab

# %% [markdown]
# - erste drei Reihen

# %%
df
# Out:
#          #               Player    GP    MIN    PTS    FGM    FGA   FG%   3PM  \
# 0        1  Kareem Abdul-Jabbar  1560  57446  38387  15837  28307  55.9     1
# 1        2          Karl Malone  1476  54852  36928  13528  26210  51.6    85
# 2        3          Kobe Bryant  1346  48643  33643  11719  26200  44.7  1827
# 3        4       Michael Jordan  1072  41010  32292  12192  24537  49.7   581
# 4        5     Wilt Chamberlain  1045  47859  31419  12681  23497  54.0     -
# 5        6        Dirk Nowitzki  1471  50572  31187  11034  23358  47.2  1918
# 6        7         LeBron James  1143  44297  31038  11280  22383  50.4  1616
# 7        8     Shaquille O'Neal  1207  41917  28596  11330  19457  58.2     1
# 8        9         Moses Malone  1329  45071  27409   9435  19225  49.1     8
# 9       10          Elvin Hayes  1303  50000  27313  10976  24272  45.2     5
# 10      11      Hakeem Olajuwon  1238  44218  26946  10749  20991  51.2    25
# 11      12      Oscar Robertson  1040  43886  26710   9508  19620  48.5     -
# 12      13    Dominique Wilkins  1074  38115  26668   9963  21589  46.1   711
# 13      14           Tim Duncan  1392  47367  26496  10285  20334  50.6    30
# 14      15          Paul Pierce  1343  45879  26397   8668  19465  44.5  2143
# 15      16        John Havlicek  1270  46471  26395  10513  23930  43.9     -
# 16      17        Kevin Garnett  1462  50412  26071  10505  21142  49.7   174
# 17      18         Alex English  1193  38063  25613  10659  21036  50.7    18
# 18      19      Carmelo Anthony  1054  37834  25417   9088  20240  44.9  1341
# 19      20        Reggie Miller  1389  47620  25279   8241  17499  47.1  2560
# 20      21           Jerry West   932  36571  25192   9016  19032  47.4     -
# 21      22         Vince Carter  1405  44164  24868   8990  20567  43.7  2106
# 22      23        Patrick Ewing  1183  40594  24815   9702  19241  50.4    19
# 23      24            Ray Allen  1300  46350  24505   8567  18955  45.2  2973
# 24      25        Allen Iverson   914  37582  24368   8467  19906  42.5  1059
# 1221    12  ...  69.3   561    932   1493   248   153   172   258  42.8  45.8
# 1222    96  ...  81.1   424    863   1287   284   159   153   325  45.2  52.5
# 1223   449  ...  70.6   147    410    557   501   230    38   255  45.9  48.9
# 1224   328  ...  78.5   388    616   1004   291   164    76   236  49.3  54.7
# 1225   205  ...  56.1   596   2051   2647   171   126  2086   451  42.0  44.1
# 1226   523  ...  78.3   275    759   1034   436   157   121   341  45.0  48.5
# 1227     3  ...  44.4   644    897   1541   190   152   306   299  47.4  47.9
# 1228     1  ...  65.8   437    732   1169   143   182   282   253  53.0  56.3
# 1229   130  ...  68.4   585   1214   1799   392   256    51   226  51.5  55.4
# 1230    68  ...  69.3   506    554   1060   250   325   138   168  46.2  49.6
# 1231     6  ...  46.7   834   1385   2219   270   227   630   355  42.8  44.1
# 1232    16  ...  49.4   472    491    963   229   136   154   308  52.0  52.8
# 1233    10  ...  55.1   479    764   1243   105   136   691   231  44.7  47.5
# 1234     0  ...  66.2   562    791   1353    99   127   531   227  51.3  55.8
# 1235     9  ...  64.9   287    731   1018   186    82   137   250  46.9  51.7
# 1236    16  ...  52.7   559    598   1157   181   116   102   206  45.7  48.2
# 1237     3  ...  45.9   729    903   1632   250   199   193   273  40.7  43.3
#
# [1238 rows x 23 columns]

# %%
df.head(3)
# Out:
#    #               Player    GP    MIN    PTS    FGM    FGA   FG%   3PM   3PA  \
# 0  1  Kareem Abdul-Jabbar  1560  57446  38387  15837  28307  55.9     1    18
# 1  2          Karl Malone  1476  54852  36928  13528  26210  51.6    85   310
# 2  3          Kobe Bryant  1346  48643  33643  11719  26200  44.7  1827  5546
#
#    ...   FT%  OREB   DREB    REB   AST   STL   BLK   TOV  eFG%   TS%
# 0  ...  72.1  2975   9394  17440  5660  1160  3189  2527  55.9  59.2
# 1  ...  74.2  3562  11406  14968  5248  2085  1145  4524  51.8  57.7
# 2  ...  83.7  1499   5548   7047  6306  1944   640  4010  48.2  55.0
#
# [3 rows x 23 columns]

# %% [markdown]
# - Anzahl der Zeilen und Spalten

# %%
df.shape
# Out:
# (1238, 23)

# %% [markdown]
# - Spaltennamen und Datentypen

# %%
df.dtypes
# Out:
# #           int64
# Player     object
# GP          int64
# MIN         int64
# PTS         int64
# FGM         int64
# FGA         int64
# FG%       float64
# 3PM        object
# 3PA        object
# 3P%        object
# FTM         int64
# FTA         int64
# FT%       float64
# OREB       object
# DREB       object
# REB         int64
# AST         int64
# STL        object
# BLK        object
# TOV        object
# eFG%      float64
# TS%       float64
# dtype: object

# %% [markdown]
# ## Wer ist der beste Basketballspieler aller Zeiten?

# %% [markdown]
# Diese Leitfrage wird uns durch dieses Notebook begleiten.
#
# Für die NBA ist offensichtlich klar: Es ist **Kareem Abdul-Jabbar**.
#
# Das zeigt sich, wenn wir nochmals die obersten drei Zeilen anzeigen:

# %%
df.head(3)
# Out:
#    #               Player    GP    MIN    PTS    FGM    FGA   FG%   3PM   3PA  \
# 0  1  Kareem Abdul-Jabbar  1560  57446  38387  15837  28307  55.9     1    18
# 1  2          Karl Malone  1476  54852  36928  13528  26210  51.6    85   310
# 2  3          Kobe Bryant  1346  48643  33643  11719  26200  44.7  1827  5546
#
#    ...   FT%  OREB   DREB    REB   AST   STL   BLK   TOV  eFG%   TS%
# 0  ...  72.1  2975   9394  17440  5660  1160  3189  2527  55.9  59.2
# 1  ...  74.2  3562  11406  14968  5248  2085  1145  4524  51.8  57.7
# 2  ...  83.7  1499   5548   7047  6306  1944   640  4010  48.2  55.0
#
# [3 rows x 23 columns]

# %% [markdown]
# Doch: basierend auf welcher Metrik kommt die NBA zu diesem Schluss?
#
# Gibt es auch noch andere Varianten, diese Rangliste zu erstellen?
#
# Und vor allem: Wo zur Hölle ist **Michael Jordan**??

# %% [markdown]
# ## Einträge filtern

# %% [markdown]
# ### Die erste Suche

# %% [markdown]
# Die Syntax, mit dem man in Pandas einzelne Einträge aus dem Datenset herausfiltert, funktioniert, wie nicht anders zu erwarten, mit eckigen Klammern.

# %%
df[df['Player'] == 'Michael Jordan'] #wir schauen hier, wo michael jordan ist
# Out:
#    #          Player    GP    MIN    PTS    FGM    FGA   FG%  3PM   3PA  ...  \
# 3  4  Michael Jordan  1072  41010  32292  12192  24537  49.7  581  1778  ...
#
#     FT%  OREB  DREB   REB   AST   STL  BLK   TOV  eFG%   TS%
# 3  83.5  1668  5004  6672  5633  2514  893  2924  50.9  56.9
#
# [1 rows x 23 columns]

# %% [markdown]
# Michael Jordan steht also auf Rang vier der ewigen Bestenliste der NBA (der Rang ist in der ersten Spalte mit dem Titel "`#`" angegeben)

# %% [markdown]
# Schauen wir uns diesen Code etwas genauer an. Zuerst den inneren Teil:

# %%
df['Player'] == 'Michael Jordan' #wir überprüfens nur, es ist eine frage, nicht etwas das wir setzen
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1208    False
# 1209    False
# 1210    False
# 1211    False
# 1212    False
# 1213    False
# 1214    False
# 1215    False
# 1216    False
# 1217    False
# 1218    False
# 1219    False
# 1220    False
# 1221    False
# 1222    False
# 1223    False
# 1224    False
# 1225    False
# 1226    False
# 1227    False
# 1228    False
# 1229    False
# 1230    False
# 1231    False
# 1232    False
# 1233    False
# 1234    False
# 1235    False
# 1236    False
# 1237    False
# Name: Player, Length: 1238, dtype: bool

# %% [markdown]
# Was ist das für ein Datentyp?

# %%
type(df['Player'] == 'Michael Jordan')
# Out:
# pandas.core.series.Series

# %% [markdown]
# Speichern wir nun diese Serie in einer separaten Variable ab ...

# %%
jordan = df['Player'] == 'Michael Jordan' #wir definieren den filter

# %%
jordan
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1208    False
# 1209    False
# 1210    False
# 1211    False
# 1212    False
# 1213    False
# 1214    False
# 1215    False
# 1216    False
# 1217    False
# 1218    False
# 1219    False
# 1220    False
# 1221    False
# 1222    False
# 1223    False
# 1224    False
# 1225    False
# 1226    False
# 1227    False
# 1228    False
# 1229    False
# 1230    False
# 1231    False
# 1232    False
# 1233    False
# 1234    False
# 1235    False
# 1236    False
# 1237    False
# Name: Player, Length: 1238, dtype: bool

# %% [markdown]
# ... und setzen wir diese Variable nochmals in den äusseren Ausdruck ein:

# %%
df[jordan] #wir sagen: wende diesen filter an
# Out:
#    #          Player    GP    MIN    PTS    FGM    FGA   FG%  3PM   3PA  ...  \
# 3  4  Michael Jordan  1072  41010  32292  12192  24537  49.7  581  1778  ...
#
#     FT%  OREB  DREB   REB   AST   STL  BLK   TOV  eFG%   TS%
# 3  83.5  1668  5004  6672  5633  2514  893  2924  50.9  56.9
#
# [1 rows x 23 columns]

# %% [markdown]
# Fassen wir zusammen:
# - Wir picken uns zuerst eine Serie heraus: `df['Player']`
# - Dann testen wir jedes Element der Serie mit einem Vergleichsoperator `df['Player'] == 'Michael Jordan'`
# - Es entsteht dabei eine neue Serie mit True/False-Einträgen (boolean)
# - Nun "filtern" wir das dataframe mit dieser True/False-Serie: `df[..`(False-False-True-False)`...]`

# %% [markdown]
# ### Filtern mit Vergleichsoperatoren

# %% [markdown]
# Es gibt diverse Vergleichsoperatoren:
# - `==` gleich
# - `<` kleiner als
# - `<=` kleiner gleich
# - `>` grösser als
# - `>=` grösser gleich
# - `!=` nicht gleich

# %% [markdown]
# **Beispiel:** Alle Spieler, die mehr als 1500 Spiele absolviert haben

# %%
df[df['GP'] > 1500]
# Out:
#      #               Player    GP    MIN    PTS    FGM    FGA   FG%  3PM  \
# 0    1  Kareem Abdul-Jabbar  1560  57446  38387  15837  28307  55.9    1
# 26  27        Robert Parish  1611  45704  23334   9614  17914  53.7    0
# 44  45        John Stockton  1504  47766  19711   7039  13658  51.5  845
#
#      3PA  ...   FT%  OREB   DREB    REB    AST   STL   BLK   TOV  eFG%   TS%
# 0     18  ...  72.1  2975   9394  17440   5660  1160  3189  2527  55.9  59.2
# 26     6  ...  72.1  4598  10117  14715   2180  1219  2361  3183  53.7  57.1
# 44  2202  ...  82.6   966   3085   4051  15806  3265   315  4244  54.6  60.8
#
# [3 rows x 23 columns]

# %% [markdown]
# **Beispiel:**: Alle Spieler, die mehr als 30'000 Punkte gesammelt haben

# %%
df[df['PTS'] > 30000]
# Out:
#    #               Player    GP    MIN    PTS    FGM    FGA   FG%   3PM   3PA  \
# 0  1  Kareem Abdul-Jabbar  1560  57446  38387  15837  28307  55.9     1    18
# 1  2          Karl Malone  1476  54852  36928  13528  26210  51.6    85   310
# 2  3          Kobe Bryant  1346  48643  33643  11719  26200  44.7  1827  5546
# 3  4       Michael Jordan  1072  41010  32292  12192  24537  49.7   581  1778
# 4  5     Wilt Chamberlain  1045  47859  31419  12681  23497  54.0     -     -
# 5  6        Dirk Nowitzki  1471  50572  31187  11034  23358  47.2  1918  5005
# 6  7         LeBron James  1143  44297  31038  11280  22383  50.4  1616  4701
#
#    ...   FT%  OREB   DREB    REB   AST   STL   BLK   TOV  eFG%   TS%
# 0  ...  72.1  2975   9394  17440  5660  1160  3189  2527  55.9  59.2
# 1  ...  74.2  3562  11406  14968  5248  2085  1145  4524  51.8  57.7
# 2  ...  83.7  1499   5548   7047  6306  1944   640  4010  48.2  55.0
# 3  ...  83.5  1668   5004   6672  5633  2514   893  2924  50.9  56.9
# 4  ...  51.1     -      -  23924  4643     -     -     -  54.0  54.7
# 5  ...  87.9  1463   9868  11331  3616  1201  1263  2476  51.3  57.8
# 6  ...  73.9  1386   7029   8415  8208  1865   888  3966  54.0  58.6
#
# [7 rows x 23 columns]

# %% [markdown]
# (Hier wäre also das Kriterium, auf dem die NBA-Rangliste basiert!)

# %% [markdown]
# ### Logische Operatoren

# %% [markdown]
# Und es gibt diverse logische Operatoren:
# - `&` logisches UND
# - `|` logisches ODER
# - `~` logisches NICHT
#
# Beim kombinieren, beachte die Klammern!

# %% [markdown]
# **Beispiel**: Alle Spieler, die entweder Michael Jordan heissen oder mehr als 1500 Spiele absolviert haben

# %%
df[(df['Player'] == 'Michael Jordan') | (df['GP'] > 1500)]  #erstes Kriterium  | zweites kriterium
# Out:
#      #               Player    GP    MIN    PTS    FGM    FGA   FG%  3PM  \
# 0    1  Kareem Abdul-Jabbar  1560  57446  38387  15837  28307  55.9    1
# 3    4       Michael Jordan  1072  41010  32292  12192  24537  49.7  581
# 26  27        Robert Parish  1611  45704  23334   9614  17914  53.7    0
# 44  45        John Stockton  1504  47766  19711   7039  13658  51.5  845
#
#      3PA  ...   FT%  OREB   DREB    REB    AST   STL   BLK   TOV  eFG%   TS%
# 0     18  ...  72.1  2975   9394  17440   5660  1160  3189  2527  55.9  59.2
# 3   1778  ...  83.5  1668   5004   6672   5633  2514   893  2924  50.9  56.9
# 26     6  ...  72.1  4598  10117  14715   2180  1219  2361  3183  53.7  57.1
# 44  2202  ...  82.6   966   3085   4051  15806  3265   315  4244  54.6  60.8
#
# [4 rows x 23 columns]

# %% [markdown]
# **Beispiel**: Alle Spieler, die nicht Michael Jordan heissen und nicht weniger als 30'000 Punkte gesammelt haben

# %%
df[~(df['Player'] == 'Michael Jordan') & ~(df['PTS'] < 30000)]
# Out:
#    #               Player    GP    MIN    PTS    FGM    FGA   FG%   3PM   3PA  \
# 0  1  Kareem Abdul-Jabbar  1560  57446  38387  15837  28307  55.9     1    18
# 1  2          Karl Malone  1476  54852  36928  13528  26210  51.6    85   310
# 2  3          Kobe Bryant  1346  48643  33643  11719  26200  44.7  1827  5546
# 4  5     Wilt Chamberlain  1045  47859  31419  12681  23497  54.0     -     -
# 5  6        Dirk Nowitzki  1471  50572  31187  11034  23358  47.2  1918  5005
# 6  7         LeBron James  1143  44297  31038  11280  22383  50.4  1616  4701
#
#    ...   FT%  OREB   DREB    REB   AST   STL   BLK   TOV  eFG%   TS%
# 0  ...  72.1  2975   9394  17440  5660  1160  3189  2527  55.9  59.2
# 1  ...  74.2  3562  11406  14968  5248  2085  1145  4524  51.8  57.7
# 2  ...  83.7  1499   5548   7047  6306  1944   640  4010  48.2  55.0
# 4  ...  51.1     -      -  23924  4643     -     -     -  54.0  54.7
# 5  ...  87.9  1463   9868  11331  3616  1201  1263  2476  51.3  57.8
# 6  ...  73.9  1386   7029   8415  8208  1865   888  3966  54.0  58.6
# 1223   449  ...  70.6   147    410    557   501   230    38   255  45.9  48.9
# 1224   328  ...  78.5   388    616   1004   291   164    76   236  49.3  54.7
# 1225   205  ...  56.1   596   2051   2647   171   126  2086   451  42.0  44.1
# 1226   523  ...  78.3   275    759   1034   436   157   121   341  45.0  48.5
# 1227     3  ...  44.4   644    897   1541   190   152   306   299  47.4  47.9
# 1228     1  ...  65.8   437    732   1169   143   182   282   253  53.0  56.3
# 1229   130  ...  68.4   585   1214   1799   392   256    51   226  51.5  55.4
# 1230    68  ...  69.3   506    554   1060   250   325   138   168  46.2  49.6
# 1231     6  ...  46.7   834   1385   2219   270   227   630   355  42.8  44.1
# 1232    16  ...  49.4   472    491    963   229   136   154   308  52.0  52.8
# 1233    10  ...  55.1   479    764   1243   105   136   691   231  44.7  47.5
# 1234     0  ...  66.2   562    791   1353    99   127   531   227  51.3  55.8
# 1235     9  ...  64.9   287    731   1018   186    82   137   250  46.9  51.7
# 1236    16  ...  52.7   559    598   1157   181   116   102   206  45.7  48.2
# 1237     3  ...  45.9   729    903   1632   250   199   193   273  40.7  43.3
#
# [1238 rows x 23 columns]

# %% [markdown]
# **Quiz:** Finden Sie alle Spieler, die weniger als 1000 Turnovers (Ballverluste, TOV) auf ihrem Konto haben und eine Dreipunktewurfquote (3P%) über 50 Prozent.

# %%
#Antwort
df[(df['TOV']) < 1000 & (df['3P%'] > 50)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-a54c0c2d8128> in <module>
#       1 #Antwort
# ----> 2 df[(df['TOV']) < 1000 & (df['3P%'] > 50)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1601         result = libops.vec_compare(x, y, op)
#    1602     else:
# -> 1603         result = libops.scalar_compare(x, y, op)
#    1604     return result
#    1605
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# **Oops!**
#
# Was ging hier schief??

# %% [markdown]
# Pandas sagt: `TypeError`. Was kann das heissen?
#
# Checken wir nochmals die Datentypen.

# %%
df.dtypes
# Out:
# #           int64
# Player     object
# GP          int64
# MIN         int64
# PTS         int64
# FGM         int64
# FGA         int64
# FG%       float64
# 3PM        object
# 3PA        object
# 3P%        object
# FTM         int64
# FTA         int64
# FT%       float64
# OREB       object
# DREB       object
# REB         int64
# AST         int64
# STL        object
# BLK        object
# TOV        object
# eFG%      float64
# TS%       float64
# dtype: object

# %% [markdown]
# Offensichtlich wurden einige Spalten als `object` und nicht als `int64` oder `float64` erfasst.
#
# Zum Beispiel eben die Spalte TOV. Schauen wir sie nochmals genauer an.

# %%
df['TOV']
# Out:
# 0       2527
# 1       4524
# 2       4010
# 3       2924
# 4          -
# 5       2476
# 6       3966
# 7       3310
# 8       3804
# 9       1358
# 10      3667
# 11         -
# 12      2669
# 13      3381
# 14      3532
# 15       204
# 16      3179
# 17      2821
# 18      2824
# 19      2409
# 20         -
# 21      2509
# 22      3537
# 23      2709
# 24      3262
# 25      3376
# 26      3183
# 27      2503
# 28         -
# 29      2977
#         ...
# 1208     476
# 1209     331
# 1210     384
# 1211     428
# 1212     253
# 1213     217
# 1214     321
# 1215     386
# 1216     487
# 1217     249
# 1218     340
# 1219     355
# 1220     543
# 1221     258
# 1222     325
# 1223     255
# 1224     236
# 1225     451
# 1226     341
# 1227     299
# 1228     253
# 1229     226
# 1230     168
# 1231     355
# 1232     308
# 1233     231
# 1234     227
# 1235     250
# 1236     206
# 1237     273
# Name: TOV, Length: 1238, dtype: object

# %% [markdown]
# Einige Spieler haben bei TOV keine Zahlen drin, sondern fehlende Werte: -
#
# Wir müssen das korrigieren.

# %% [markdown]
# ## Introducing: nan

# %% [markdown]
# Pandas hat für fehlende Werte kein Sonderzeichen, sondern einen speziellen Datentyp: nan (not a number)

# %% [markdown]
# Wir müssen irgendwie dafür sorgen, dass die Bindestriche in dieser Tabelle durch nan's ersetzt werden.
#
# Nur so werden wir die Kalkulationen für die betreffenden Felder ausführen können.

# %% [markdown]
# Es gibt diverse Tricks, um Daten zu putzen und fehlende Werte als nan zu klassifizieren.
#
# Der einfachste: Die Daten einfach nochmal neu öffnen, mit einer speziellen Zusatzangabe: `na_values`

# %%
df = pd.read_excel(path, na_values='-') #ich kann das ganze immer wieder neu einlesen und ergänzen

# %% [markdown]
# Et voilà: Hier sind unsere Datentypen

# %%
df.dtypes
# Out:
# #           int64
# Player     object
# GP          int64
# MIN         int64
# PTS         int64
# FGM         int64
# FGA         int64
# FG%       float64
# 3PM       float64
# 3PA       float64
# 3P%       float64
# FTM         int64
# FTA         int64
# FT%       float64
# OREB      float64
# DREB      float64
# REB         int64
# AST         int64
# STL       float64
# BLK       float64
# TOV       float64
# eFG%      float64
# TS%       float64
# dtype: object

# %% [markdown]
# Und hier unsere Spieler mit weniger als 1000 Turnovers und Dreipunktewurfquote über 50 Prozent.

# %%
df[(df['TOV'] < 1000) & (df['3P%'] > 50)]
# Out:
#        #         Player   GP    MIN    PTS   FGM    FGA   FG%   3PM   3PA  \
# 111  112  Pete Maravich  658  24316  15948  6187  14025  44.1  10.0  15.0
#
#      ...   FT%   OREB    DREB   REB   AST    STL    BLK    TOV  eFG%   TS%
# 111  ...  82.0  426.0  1421.0  2747  3563  587.0  108.0  530.0  44.1  50.0
#
# [1 rows x 23 columns]

# %% [markdown]
# Wow, **Pete Maravich** ist der einzige Spieler, der das geschafft hat! Er ist der beste Spieler der NBA aller Zeiten!!

# %% [markdown]
# Hier ein Video von Pete Maravich: https://www.youtube.com/watch?v=cL74uXq5l2o
#
# ... allerdings hat Pete Maravich auch nur in 658 Spielen gespielt, deutlich weniger als Kareem Abdul-Jabbar mit seinen 1560 Spielen.

# %% [markdown]
# Wie wäre es also mit einem neuen Kriterium: Ballverluste pro Spiel? Wer schneidet hier besser ab, Maravich oder Abdul-Jabbar?

# %% [markdown]
# ## Neue Spalten erstellen

# %% [markdown]
# Bislang haben wir unsere Vergleiche mit bestehenden Spalten angestellt. Nun müssen wir eine neue Spalte erstellen.

# %% [markdown]
# Wir nennen sie "TOV%" und sagen Pandas, dafür die Anzahl der Ballverluste durch die Anzahl der Spiele zu dividieren.

# %%
df['TOV%'] = df['TOV'] / df['GP']  #turnoverquote pro spieler. Das ist dann unsere neue spalte. hier turnovers/spiel

# %%
df.head()
# Out:
#    #               Player    GP    MIN    PTS    FGM    FGA   FG%     3PM  \
# 0  1  Kareem Abdul-Jabbar  1560  57446  38387  15837  28307  55.9     1.0
# 1  2          Karl Malone  1476  54852  36928  13528  26210  51.6    85.0
# 2  3          Kobe Bryant  1346  48643  33643  11719  26200  44.7  1827.0
# 3  4       Michael Jordan  1072  41010  32292  12192  24537  49.7   581.0
# 4  5     Wilt Chamberlain  1045  47859  31419  12681  23497  54.0     NaN
#
#       3PA  ...    OREB     DREB    REB   AST     STL     BLK     TOV  eFG%  \
# 0    18.0  ...  2975.0   9394.0  17440  5660  1160.0  3189.0  2527.0  55.9
# 1   310.0  ...  3562.0  11406.0  14968  5248  2085.0  1145.0  4524.0  51.8
# 2  5546.0  ...  1499.0   5548.0   7047  6306  1944.0   640.0  4010.0  48.2
# 3  1778.0  ...  1668.0   5004.0   6672  5633  2514.0   893.0  2924.0  50.9
# 4     NaN  ...     NaN      NaN  23924  4643     NaN     NaN     NaN  54.0
#
#     TS%      TOV%
# 0  59.2  1.619872
# 1  57.7  3.065041
# 2  55.0  2.979198
# 3  56.9  2.727612
# 4  54.7       NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# Schaun wir mal, wer nun besser abschneidet: Pete Maravich oder Kareem Abdul-Jabbar?

# %%
df[(df['Player'] == 'Pete Maravich') | (df['Player'] == 'Kareem Abdul-Jabbar')]
# Out:
#        #               Player    GP    MIN    PTS    FGM    FGA   FG%   3PM  \
# 0      1  Kareem Abdul-Jabbar  1560  57446  38387  15837  28307  55.9   1.0
# 111  112        Pete Maravich   658  24316  15948   6187  14025  44.1  10.0
#
#       3PA  ...    OREB    DREB    REB   AST     STL     BLK     TOV  eFG%  \
# 0    18.0  ...  2975.0  9394.0  17440  5660  1160.0  3189.0  2527.0  55.9
# 111  15.0  ...   426.0  1421.0   2747  3563   587.0   108.0   530.0  44.1
#
#       TS%      TOV%
# 0    59.2  1.619872
# 111  50.0  0.805471
#
# [2 rows x 24 columns]

# %% [markdown]
# Wir können die üblichen mathematischen Operatoren verwenden, um auf diese Weise Spalten zu erzeugen:
# - `+`, `-`, `*`, `/`, `**`, `%`, `//` (die komplette Liste der Operatoren: https://www.tutorialspoint.com/python/python_basic_operators.htm)

# %% [markdown]
# **Quiz:** Erstellen Sie eine neue Spalte ("TOT") mit dem Total der Rebounds, Assists, Steals und Blocks, die ein Spieler in seiner Karriere gesammelt hat.

# %%
#Antwort
df['TOT'] = df['REB'] + df['AST'] + df['STL'] + df['BLK']

# %% [markdown]
# **Quiz:** Welche zehn Spieler haben die grössten Tot-Werte aller Zeiten?

# %%
#Antwort
df.sort_values('TOT', ascending=False)
# 44    54.6  60.8  2.821809  23437.0
# 13    50.7  55.1  2.428879  23361.0
# 10    51.3  55.3  2.962036  22798.0
# 9     45.2  49.1  1.042210  21312.0
# 8     49.1  56.9  2.862302  20830.0
# 26    53.7  57.1  1.975791  20475.0
# 7     58.2  58.6  2.742336  19596.0
# 6     54.0  58.6  3.469816  19376.0
# 25    55.8  61.2  3.146319  19297.0
# 76    53.3  61.0  3.869757  18798.0
# 317   50.9  53.7  0.588415  18586.0
# 22    50.5  55.3  2.989856  17852.0
# 11    48.5  56.4       NaN  17772.0
# 153   42.1  47.0       NaN  17717.0
# 69    58.3  59.9  2.940097  17658.0
# 38    51.3  56.5  2.192308  17568.0
# 5     51.3  57.8  1.683209  17411.0
# 260   51.8  57.3  1.816890  17382.0
# 37    51.9  58.3  2.448835  17280.0
# 223   47.4  52.6  2.172387  17157.0
# 218   48.1  52.2  2.434414  17022.0
# 32    51.4  56.4  3.139353  16980.0
# 31    49.6  52.8  2.269663  16965.0
# 34    51.6  55.4       NaN  16885.0
# 55    50.4  53.6  2.764856  16883.0
# 95    54.9  58.7  2.130069  16843.0
# ...    ...   ...       ...      ...
# 850   38.9  43.2       NaN      NaN
# 852   39.8  43.8       NaN      NaN
# 867   35.6  41.6       NaN      NaN
# 872   42.1  48.2       NaN      NaN
# 875   38.7  44.2       NaN      NaN
# 882   36.9  42.3       NaN      NaN
# 905   35.2  39.4       NaN      NaN
# 910   41.8  47.4       NaN      NaN
# 929   33.7  38.6       NaN      NaN
# 931   38.2  44.1       NaN      NaN
# 937   34.9  40.9       NaN      NaN
# 946   36.6  43.8       NaN      NaN
# 951   40.5  44.7       NaN      NaN
# 972   42.9  47.7       NaN      NaN
# 1008  41.0  45.1       NaN      NaN
# 1019  41.6  45.2       NaN      NaN
# 1020  34.7  40.2       NaN      NaN
# 1051  31.3  37.2       NaN      NaN
# 1053  34.1  41.8       NaN      NaN
# 1078  34.6  38.4       NaN      NaN
# 1084  42.9  46.7       NaN      NaN
# 1095  34.5  37.6       NaN      NaN
# 1110  35.4  40.1       NaN      NaN
# 1125  39.1  43.0       NaN      NaN
# 1141  39.3  43.6       NaN      NaN
# 1150  33.9  41.8       NaN      NaN
# 1156  43.6  47.5       NaN      NaN
# 1179  27.2  30.9       NaN      NaN
# 1197  37.2  42.5       NaN      NaN
# 1205  37.6  43.5       NaN      NaN
#
# [1238 rows x 25 columns]

# %% [markdown]
# ## Sortieren nach bestimmten Kriterien

# %% [markdown]
# Wir haben die Funktion `sort_values()` bereits kennengelernt beim Sortieren von einfachen Serien.
#
# Nun benutzen wir sie, um ganze Dataframes zu sortieren. Dabei müssen wir jeweils angeben, nach welchen Spalten wir sortieren wollen und in welcher Richtung wir die Einträge anzeigen lassen.

# %% [markdown]
# **Beispiel:** Sortieren nach der Anzahl Ballverluste pro Spiel, mit der tiefsten Quote zuerst (wir zeigen nur die ersten 10 Einträge an)

# %%
df.sort_values('TOV%').head(10)
# Out:
#          #           Player   GP    MIN    PTS   FGM    FGA   FG%  3PM  3PA  \
# 1103  1104   Steve Kuberski  568   7897   3114  1254   3005  41.7  NaN  NaN
# 890    891  Zaid Abdul-Aziz  505  11023   4557  1769   4138  42.8  NaN  NaN
# 1099  1099   Dale Schlueter  586   9624   3130  1176   2366  49.7  NaN  NaN
# 1159  1160        Dave Wohl  410   8142   2553  1015   2361  43.0  NaN  NaN
# 885    886   Tom Boerwinkle  635  14387   4596  1863   4109  45.3  NaN  NaN
# 226    227   Cazzie Russell  817  22213  12377  5172  11154  46.4  NaN  NaN
# 258    259      Dick Snyder  964  25676  11755  4890  10019  48.8  NaN  NaN
# 932    933    Howard Porter  457   8534   4215  1838   3922  46.9  NaN  NaN
# 1089  1090   Willie Norwood  430   7341   3209  1218   2494  48.8  NaN  NaN
# 887    888     Curtis Perry  480  13656   4578  1904   4188  45.5  NaN  NaN
#
#       ...    DREB   REB   AST    STL    BLK   TOV  eFG%   TS%      TOV%  \
# 1103  ...   519.0  2146   338   38.0   28.0   2.0  41.7  46.4  0.003521
# 890   ...  1124.0  4065   601  131.0  205.0  11.0  42.8  47.9  0.021782
# 1099  ...   519.0  3034   920   67.0   91.0  15.0  49.7  54.5  0.025597
# 1159  ...   236.0   558  1397  219.0   18.0  16.0  43.0  47.9  0.039024
# 885   ...  1220.0  5745  2007  110.0  138.0  26.0  45.3  49.1  0.040945
# 226   ...   685.0  3068  1838  239.0   33.0  35.0  46.4  50.6  0.042840
# 258   ...   740.0  2732  2767  300.0  157.0  84.0  48.8  53.1  0.087137
# 932   ...  1070.0  1872   211  156.0  212.0  55.0  46.9  50.0  0.120350
# 1089  ...   564.0  1597   364  218.0   22.0  56.0  48.8  53.8  0.130233
# 887   ...  1950.0  4239   906  379.0  291.0  63.0  45.5  49.0  0.131250
#
#          TOT
# 1103  2550.0
# 890   5002.0
# 1099  4112.0
# 1159  2192.0
# 885   8000.0
# 226   5178.0
# 258   5956.0
# 932   2451.0
# 1089  2201.0
# 887   5815.0
#
# [10 rows x 25 columns]

# %% [markdown]
# **Beispiel:** Sortieren nach der Wurfquote pro Spiel, mit der höchsten Quote zuerst (wir zeigen nur die ersten 10 Einträge an)

# %%
df.sort_values('FG%', ascending=False).head(10)

# %% [markdown]
# Etwas nervig: Auch wenn wir nach einzelnen Kriterien sortieren, zeigt Pandas immer die ganze Tabelle an.

# %% [markdown]
# ## Einzelne Spalten anzeigen

# %% [markdown]
# Wir können dem entgegenwirken, indem wir nur einzelne Spalten aus dem Dataframe selektieren.
#
# Dazu geben wir eine Liste der Felder an, die wir anzeigen wollen.

# %% [markdown]
# **Beispiel:** Die fünf besten Spieler der Geschichte: Name, Punkte, Wurfquote, Ballverlustquote

# %% [markdown]
# Zuerst die Liste...

# %%
felderliste = ['Player', 'PTS', 'FG%', 'TOV%']

# %%
felderliste
# Out:
# ['Player', 'PTS', 'FG%', 'TOV%']

# %% [markdown]
# ... dann die Abfrage

# %%
df[felderliste].head(5)
# Out:
#                 Player    PTS   FG%      TOV%
# 0  Kareem Abdul-Jabbar  38387  55.9  1.619872
# 1          Karl Malone  36928  51.6  3.065041
# 2          Kobe Bryant  33643  44.7  2.979198
# 3       Michael Jordan  32292  49.7  2.727612
# 4     Wilt Chamberlain  31419  54.0       NaN

# %% [markdown]
# Oder beides in einem Schritt:

# %%
df[['Player', 'PTS', 'FG%', 'TOV%']].head(5)
# Out:
#                 Player    PTS   FG%      TOV%
# 0  Kareem Abdul-Jabbar  38387  55.9  1.619872
# 1          Karl Malone  36928  51.6  3.065041
# 2          Kobe Bryant  33643  44.7  2.979198
# 3       Michael Jordan  32292  49.7  2.727612
# 4     Wilt Chamberlain  31419  54.0       NaN

# %% [markdown]
# Wir haben nun alle Zutaten beisammen, um unsere eigentliche Frage zu beantworten:

# %% [markdown]
# ## Wer ist der beste Basketballer aller Zeiten?

# %% [markdown]
# Natürlich erstellen wir dazu unsere eigene Kennzahl, anhand derer wir die Rangliste erstellen!

# %% [markdown]
# **TODO:** Erfinden Sie eine eigene Kennzahl, basierend auf einer Kombination von bestehenden Statistiken (Wurfquote, Rebounds, etc.). Speichern Sie die Kennzahl in einer neuen Spalte namens "KEN" ab. Sortieren Sie die Spieler nach dieser Kennzahl und zeigen Sie die Top 10 in einer Tabelle mit den folgenden Spalten an: Name, KEN. Speichern Sie diese Tabelle in einem neuen Dataframe namens "Top10" ab.

# %%
# df['KEN'] erstellen

df['KEN'] = df['PTS'] / df['MIN']

# %%
# df nach 'KEN' sortieren, Top 10
df.sort_values('KEN', ascending=False).head(10)
# Out:
#          #           Player    GP    MIN    PTS    FGM    FGA   FG%     3PM  \
# 492    493        Joe Fulks   489   4490   8003   2824   9338  30.2     NaN
# 1179  1180     John Mahnken   414   1352   2388    966   3557  27.2     NaN
# 345    346     George Mikan   439   8350  10156   3544   8783  40.4     NaN
# 495    495    Max Zaslofsky   540   6760   7990   2854   8313  34.3     NaN
# 680    681  Freddie Scolari   534   6573   6014   2132   6651  32.1     NaN
# 707    708   Connie Simmons   598   7036   5859   2180   6211  35.1     NaN
# 3        4   Michael Jordan  1072  41010  32292  12192  24537  49.7   581.0
# 39      40    George Gervin   791  26536  20708   8045  15747  51.1    77.0
# 632    633       Bob Davies   462   8617   6594   2292   6067  37.8     NaN
# 35      36     Kevin Durant   771  28603  20913   7093  14476  49.0  1433.0
#
#          3PA  ...   REB   AST     STL    BLK     TOV  eFG%   TS%      TOV%  \
# 492      NaN  ...  1379   587     NaN    NaN     NaN  30.2  37.4       NaN
# 1179     NaN  ...   533   539     NaN    NaN     NaN  27.2  30.9       NaN
# 345      NaN  ...  4167  1245     NaN    NaN     NaN  40.4  48.3       NaN
# 495      NaN  ...   864  1093     NaN    NaN     NaN  34.3  41.5       NaN
# 680      NaN  ...   857  1406     NaN    NaN     NaN  32.1  39.6       NaN
# 707      NaN  ...  2294   940     NaN    NaN     NaN  35.1  40.8       NaN
# 3     1778.0  ...  6672  5633  2514.0  893.0  2924.0  50.9  56.9  2.727612
# 39     259.0  ...  3607  2214   941.0  670.0  2137.0  51.3  57.2  2.701643
# 632      NaN  ...   980  2250     NaN    NaN     NaN  37.8  45.6       NaN
# 35    3734.0  ...  5495  3029   890.0  857.0  2428.0  53.9  61.1  3.149157
#
#           TOT       KEN
# 492       NaN  1.782405
# 1179      NaN  1.766272
# 345       NaN  1.216287
# 495       NaN  1.181953
# 680       NaN  0.914955
# 707       NaN  0.832717
# 3     15712.0  0.787418
# 39     7432.0  0.780374
# 632       NaN  0.765232
# 35    10271.0  0.731147
#
# [10 rows x 26 columns]

# %%
# Liste in neuem dataframe 'Top10' speichern (nur Spielername und KEN)
Top10 = df.sort_values('KEN', ascending=False)[['Player', 'KEN']].head(10)  #zwei klammern, weil eine liste in eckigen klammern

# %%
Top10
# Out:
#                Player       KEN
# 492         Joe Fulks  1.782405
# 1179     John Mahnken  1.766272
# 345      George Mikan  1.216287
# 495     Max Zaslofsky  1.181953
# 680   Freddie Scolari  0.914955
# 707    Connie Simmons  0.832717
# 3      Michael Jordan  0.787418
# 39      George Gervin  0.780374
# 632        Bob Davies  0.765232
# 35       Kevin Durant  0.731147

# %% [markdown]
# **Und:** Wer ist der beste NBA-Spieler aller Zeiten?

# %%
#Antwort

# %% [markdown]
# ## Resultat speichern

# %% [markdown]
# Um die Tabelle weiter zu verwenden, zum Beispiel für einen Graph in einem anderen Programm, können wir sie exportieren. Wir gehen dabei ähnlich vor wie beim öffnen, nur umgekehrt. Wir wählen dazu das Datenformat csv.

# %%
path = 'dataprojects/nba-players/meine-alltimeliste.csv'  #unter diesem pfad find ich nun die datei im jupiter notebook. 
#wenn ich keinen unterpfad eingebe, dann speichert es mir das im gleichen ort wie das notebook

# %% [markdown]
# Wichtig: Wenn wir den Index nicht mitspeichern wollen (das sind die fetten Zahlen am Rand), müssen wir das mitteilen.

# %%
Top10.to_csv(path, index=False)

# %% [markdown]
# **Check: **Hat es funktioniert?

# %%
check = pd.read_csv(path)

# %%
check
# Out:
#             Player       KEN
# 0        Joe Fulks  1.782405
# 1     John Mahnken  1.766272
# 2     George Mikan  1.216287
# 3    Max Zaslofsky  1.181953
# 4  Freddie Scolari  0.914955
# 5   Connie Simmons  0.832717
# 6   Michael Jordan  0.787418
# 7    George Gervin  0.780374
# 8       Bob Davies  0.765232
# 9     Kevin Durant  0.731147

# %% [markdown]
# ## Plotting Level 2

# %% [markdown]
# Es gibt nicht nur Bar- und Linecharts, sondern auch weitere Chartformate, die sich in Pandas recht praktisch generieren lassen.

# %% [markdown]
# ### Histogramme

# %% [markdown]
# Eine nette Funktion, um ein Datenset zu analysieren, sind Histogramme. Mit ihnen können wir ziemlich schnell sichtbar machen, wie die Werte in einer bestimmten Spalte verteilt sind.
# erklärung: Schulklasse mit unterschiedlichen noten pro schüler. Drei schüler liegen zw 5 und 6, sechs zwischen vier und fünf und so weiter. so ein verteilungsplot.
#
# Pandas stellt dazu die Funktion `hist()` zur Verfügung.

# %% [markdown]
# **Beispiel:** Die Anzahl Punkte, die ein Spieler in seiner Karriere gesammelt hat.

# %%
df['PTS'].hist()

# %% [markdown]
# Mit dem Parameter `bins` können wir das Histogramm feingliedriger gestalten:

# %%
df['PTS'].hist(bins=50) #50 verschiedene kategorien macht er dann, 50 kübel

# %% [markdown]
# Man sieht: Die Verteilung der Punkte ist ziemlich linksschief. Die allermeisten Spieler haben zwischen 5000 und 15000 Punkten gesammelt. Über 25'000 sind nur die wenigsten gekommen.

# %% [markdown]
# **Quiz:** Plotten Sie die eigene Alltime-Kennzahl in einem Histogramm. Ist die Verteilung ähnlich?

# %%
df['KEN'].hist(bins=50)

# %% [markdown]
# ### Scatterplot

# %% [markdown]
# Scatterplots eignen sich für den Vergleich von zwei Spalten. Man erhält mit ihnen rasch eine Idee davon, ob die Werte in einer Spalte mit der anderen Spalte in Zusammenhang stehen.

# %% [markdown]
# **Beispiel:** Die Anzahl gesammelter Punkte und die Wurfquote

# %%
df.plot(kind='scatter', x='PTS', y='FG%')

# %% [markdown]
# Man sieht: Auch Spieler mit einer mittelguten Wurfquote haben es im Lauf ihrer Karriere zu grossen Punktesammlern gebracht.
# Es gibt also keinen Zusammenhang

# %% [markdown]
# **Quiz:** Erforschen Sie den Zusammenhang zwischen den total gesammelten Punkten und Ihrer eigenen Kennzahl in einem Scatterplot!

# %%
#Plot
df.plot(kind='scatter', x='PTS', y='KEN')

# %% [markdown]
# Wir können den Scatterplot auch noch schöner darstellen:
#
# - mit Punkten in unterschiedlicher Grösse, entsprechend der Anzahl Punkte, die ein Spieler gesammelt hat

# %%
area = df['KEN'] * 50

# %%
area
# Out:
# 0       33.411378
# 1       33.661489
# 2       34.581543
# 3       39.370885
# 4       32.824547
# 5       30.834256
# 6       35.033975
# 7       34.110266
# 8       30.406470
# 9       27.313000
# 10      30.469492
# 11      30.431117
# 12      34.983602
# 13      27.968839
# 14      28.768064
# 15      28.399432
# 16      25.857931
# 17      33.645535
# 18      33.590157
# 19      26.542419
# 20      34.442591
# 21      28.154153
# 22      30.564862
# 23      26.434736
# 24      32.419775
# 25      30.201368
# 26      25.527306
# 27      33.933121
# 28      34.180374
# 29      29.563376
#           ...
# 1208    13.814617
# 1209    11.990752
# 1210    15.593414
# 1211    16.419327
# 1212    16.699341
# 1213    11.019756
# 1214    11.605464
# 1215    16.828687
# 1216     6.477934
# 1217    15.164413
# 1218    14.086038
# 1219    11.969487
# 1220     8.516865
# 1221    15.168943
# 1222    13.759398
# 1223    13.315482
# 1224    14.442842
# 1225     6.834502
# 1226    11.769049
# 1227    14.200109
# 1228    13.530616
# 1229    10.681684
# 1230    10.138355
# 1231     7.051892
# 1232    11.009086
# 1233     9.037262
# 1234     7.539683
# 1235    11.960368
# 1236     9.137769
# 1237     6.000670
# Name: KEN, Length: 1238, dtype: float64

# %% [markdown]
# - und grösser. Wir untersuchen: Gibt es einen Zusammenhang zwischen KEN und der Anzahl Spiele, die ein Spieler geamcht hat?

# %%
df.plot(kind='scatter', x='GP', y='KEN', s=area, alpha=0.3, figsize=(10,7))  #s steht für size, alpha ist die farbintensivität

