# %% [markdown]
# https://towardsdatascience.com/named-entity-recognition-with-nltk-and-spacy-8c4a7d88e7da

# %%
# !pip install spacy --user
# !python -m spacy download en_core_web_sm
# !python -m spacy download de_core_news_sm
# Out:
# ...
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# ...
# [+] Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# ...
#   Created wheel for de-core-news-sm: filename=de_core_news_sm-2.2.5-cp37-none-any.whl size=14907063 sha256=8bbf0b9a4e695e82b1d006f93219a6e98ecaaea1d1dfd141da773adee5880066
#   Stored in directory: C:\Users\Admin\AppData\Local\Temp\pip-ephem-wheel-cache-cj5jrbtq\wheels\ba\3f\ed\d4aa8e45e7191b7f32db4bfad565e7da1edbf05c916ca7a1ca
# Successfully built de-core-news-sm
# ...
# [+] Download and installation successful
# You can now load the model via spacy.load('de_core_news_sm')
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# ...

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
article  = '''

Air pollution is a very big deal. Its adverse effects on numerous health outcomes and general mortality are widely documented. However, our understanding of its cognitive costs is more recent and those costs are almost certainly still significantly under-emphasized. For example, cognitive effects are not mentioned in most EPA materials.

World Bank data indicate that 3.7 billion people, about half the world's population, are exposed to more than 50 µg/m³ of PM2.5 on an annual basis, 5x the unit of measure for most of the findings below.

    Chess players make more mistakes on polluted days: "We find that an increase of 10 µg/m³ raises the probability of making an error by 1.5 percentage points, and increases the magnitude of the errors by 9.4%. The impact of pollution is exacerbated by time pressure. When players approach the time control of games, an increase of 10 µg/m³, corresponding to about one standard deviation, increases the probability of making a meaningful error by 3.2 percentage points, and errors being 17.3% larger." – Künn et al 2019.
    A 3.26x (albeit with very wide CI) increase in Alzheimer's incidence for each 10 µg/m³ increase in long-term PM2.5 exposure? "Short- and long-term PM2.5 exposure was associated with increased risks of stroke (short-term odds ratio 1.01 [per µg/m³ increase in PM2.5 concentrations], 95% CI 1.01-1.02; long-term 1.14, 95% CI 1.08-1.21) and mortality (short-term 1.02, 95% CI 1.01-1.04; long-term 1.15, 95% CI 1.07-1.24) of stroke. Long-term PM2.5 exposure was associated with increased risks of dementia (1.16, 95% CI 1.07-1.26), Alzheimer's disease (3.26, 95% 0.84-12.74), ASD (1.68, 95% CI 1.20-2.34), and Parkinson's disease (1.34, 95% CI 1.04-1.73)." – Fu et al 2019. Similar effects are seen in Bishop et al 2018: "We find that a 1 µg/m³ increase in decadal PM2.5 increases the probability of a dementia diagnosis by 1.68 percentage points."
    A study of 20,000 elderly women concluded that "the effect of a 10 µg/m³ increment in long-term [PM2.5 and PM10] exposure is cognitively equivalent to aging by approximately 2 years". – Weuve et al 2013.
    "Utilizing variations in transitory and cumulative air pollution exposures for the same individuals over time in China, we provide evidence that polluted air may impede cognitive ability as people become older, especially for less educated men. Cutting annual mean concentration of particulate matter smaller than 10 µm (PM10) in China to the Environmental Protection Agency’s standard (50 µg/m³) would move people from the median to the 63rd percentile (verbal test scores) and the 58th percentile (math test scores), respectively." – Zhang et al 2018.
    Stock market returns are lower on polluted days. "This estimate indicates that a one unit increase in PM2.5 decreases the daily percentage returns by 1.7%. Put differently, a one standard deviation increase in PM2.5 decreases the daily percentage returns by 11.9%, a substantial effect on daily NYSE returns." Hayes et al 2016.
    Baseball umpires make worse decisions on polluted days. "Unique characteristics of this setting combined with high-frequency data disentangle effects of multiple pollutants and identify previously under-explored acute effects. We find a 1 ppm increase in 3 hour CO causes an 11.5% increase in the propensity of umpires to make incorrect calls and a 10 µg/m³ increase in 12-hour PM2.5 causes a 2.6% increase." Archsmith et al 2018.
    Politicians use less complex speech on polluted days. "We apply textual analysis to convert over 100,000 verbal statements made by Canadian MPs from 2006 through 2011 into—among other metrics—speech-specific Flesch-Kincaid grade-level indices. This index measures the complexity of an MP’s speech by the number of years of education needed to accurately understand it. Conditioning on individual fixed effects and other controls, we show that elevated levels of airborne fine particulate matter reduce the complexity of MPs’s speeches. A high-pollution day, defined as daily average PM2.5 concentrations greater than 15 µg/m³, causes a 2.3% reduction in same-day speech quality. To put this into perspective, this is equivalent to the removal of 2.6 months of education." Heyes et al 2019.
    "Exposure to CO2 and VOCs at levels found in conventional office buildings was associated with lower cognitive scores than those associated with levels of these compounds found in a Green building." – Allen et al 2016. The effect seems to kick in at around 1,000 ppm of CO2.

'''

# %% [markdown]
# ## Mit Spacy NLP verarbeiten

# %%
article = nlp(article)
len(article.ents)
# Out:
# 91

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 5,
#          'CARDINAL': 25,
#          'DATE': 24,
#          'QUANTITY': 4,
#          'PERCENT': 15,
#          'MONEY': 2,
#          'PERSON': 5,
#          'GPE': 6,
#          'ORDINAL': 1,
#          'TIME': 1,
#          'NORP': 1,
#          'WORK_OF_ART': 2})

# %% [markdown]
# Infos zu den Abkürzungen: https://spacy.io/api/annotation

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('95%', 8), ('polluted days', 3), ('daily', 3)]

# %%
sentences = [x for x in article.sents]
#print(sentences[2])
sentences[3]
# Out:
# For example, cognitive effects are not mentioned in most EPA materials.

# %%
displacy.render(nlp(str(sentences[4])), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Bank
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  data indicate that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.7 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about half
# ...

# %%
displacy.render(nlp(str(sentences[0])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e840d9fdb73d4262b7ac8529844c3706-0" class="displacy" width="1010" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Air</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">pollution</tspan>
# ...

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[0])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('\n\n', 'SPACE', '\n\n'),
#  ('Air', 'NOUN', 'air'),
#  ('pollution', 'NOUN', 'pollution'),
#  ('big', 'ADJ', 'big'),
#  ('deal', 'NOUN', 'deal')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[0])).ents])
# Out:
# {}

# %%
displacy.render(article, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr"></br></br>Air pollution is a very big deal. Its adverse effects on numerous health outcomes and general mortality are widely documented. However, our understanding of its cognitive costs is more recent and those costs are almost certainly still significantly under-emphasized. For example, cognitive effects are not mentioned in most
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EPA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  materials.</br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Bank
# ...

# %%
import spacy
from spacy import displacy
from collections import Counter
import de_core_news_sm
nlp = de_core_news_sm.load()

# %%
artikel = '''Noch zu machen
Allgemein:
1.	Runde
-	Tempo anschauen: Schnipsel von Infos. Verankerung im Hier und Jetzt. Nicht zu lange Vergangenheits-Passagen. Tempo reduzieren (stretchen, zoomen, Informationspolitik)
-	Langsamer erzählen, ausführlicher, detaillierter. Beim Durchgehen schauen, wo ich dehnen, wo ich straffen will
-	Anschauen, ob es eventuell längere Zeitspannen zwischen den Kapiteln braucht (zwei Minuten oder sowas)
-	Schauen, obs überladen ist
-	Mehr Szenen von rundum einbauen, damit mehr Gefühl für die Gegenwart da ist.
-	Nicht zu viel erklären!!!!!!!!!!!!!!!!!!!!!!!!!!!Peter sind beide ab und zu im man. Mona ist im Du, aber mit Mirjam. R

-	Prägende Sätze für Katharina: Du bist zu schwach, zu nett, zu lieb. Das entsprechend einfügen bzw. anpassen
-	Sie hat ein Couvert in der Tasche, das bei Ruth beschrieben wird. Dort drin stecken die Reiseunterlagen 
-	Informationspolitik
-	Versammlungsszene abgleichen mit Peters szee (kommentiert)
-	Grabsteinbilder beim Fuchs einbauen. Seine Mutter ist kürzlich gestorben. (das ist eher bei ruth, katharina und peter wichtig)


Mona: done
-	Monas Alter klar machen
-	Mona hat man-Ansätze drin
-	Mobbing-Szenen bei Mona einfügen, zeigen, dass sie als Kind/Jugendliche unbeliebt war und dass ihre Zwillingsschwester das zu nutzen wusste
-	Zeigen, dass sie eigentlich literarisch begabt wäre. Literatin. Das machte sie früher auch, schreiben. 
-	Katze oder Kater bei Mona? Merlin.
-	Prägende Sätze für Mona: Mach doch mal etwas Vernünftiges. Du hast mich umgebracht. 
-	Das letzte Mona-Kapitel lyrischer machen. Oder fallen lassen. Oder ganz anders.
-	Informationspolitik: Zerschneiden und neu zusammensetzen. Insbesondere hat es Längen im 1. Kapitel (evtl. mit Sachen aus dem zweitletzten mischen, dort hat es auch Längen. Die anderen beiden sind eigentlich okay.) Längen: bei sleeper. 

Fuchs/Ben. Done.
-	Informationspolitik Schauen, ob die chronologie klarer sein muss.
-	Brechbühl und Ben: Duzen oder siezen sie sich? Siezen mit vorname, analog gymersituation
-	Anfang überarbeiten (sequenzenhaft/Fuchs?)
-	Klären, wann Fuchs, wann Fox, wann Ben, wann von Steg. Das Namengestürm passts, weil er ja eine Identitätskrise hat, nicht so recht weiss, was er will
-	Prägende Sätze für den Fuchs: Dieses kindische Gekritzel. Das ist eines von Stegs nicht würdig. Lass doch den Unsinn. Geh besser mal an die frische Luft. Übernimm endlich Verantwortung.
-	Grabsteinbilder beim Fuchs einbauen. Seine Mutter ist kürzlich gestorben. (das ist eher bei ruth, katharina und peter wichtig)
-	Bens Vater hinkt. Er hat eine Beinprothese
-	Beerdigung einbauen, zuletzt. (hab ich das genug getan?
-	Wie läuft ein Notfallgespräch ab? So sinnvoll?
-	Die Trauer einbetten, von anfang an. Langsam preisgeben, was geschehen ist. 
-	Nicht erklären, rein erklärerisches rausstreichen,

Ruth. Done.
-	Informationspolitik; unbedingt schnippeln alles, gerade gegen schluss. Und schaeun, wie ich alles durchmischt durchziehen kann.
-	Es braucht viel mehr Gegenwartsszenen
-	Ich erzähle zu schnell, kürzere Einheiten. Violeta auch. (aus Treffen im Houdini, Kommentare in Version 4.0 farbig)
-	Prägende Sätze für Ruth: Sei nicht immer so egoistisch. Du Luder. Hexe. 
-	Schauen, ob alles zu ende erzählt ist. 
-	Solitär-Sucht konsequenter durchziehen.
-	Peters Ehering ist aus Weissgold. Bei Ruth auch so beschreiben
-	Fuchs’ Augen sind grün. So beschreiben. 
-	Grabsteinbilder beim Fuchs einbauen. Seine Mutter ist kürzlich gestorben. (das ist eher bei ruth, katharina und peter wichtig)
-	Das Amulett mit dem Smaragd ist ein Hochzeitsgeschenk von Leon. Das noch einbauen
-	Schauen, wie das mit Solitär läuft, ausprobieren. 

Violeta. Done.
-	Informationspolitik: eventuell aufschnipseln. 
-	Violeta: Ich erzähle zu schnell, kürzere Einheiten. Ruth auch. (aus Treffen im Houdini, Kommentare in Version 4.0 farbig)
-	Vegetarierin
-	Die konkreten ortsbezeichnungen und landesbezeichnungen bei violeta weg lassen. Es spielt keine rolle
-	Prägende Sätze für Violeta: Man unterbricht die Leute beim Reden nicht. Du bist zu stark.
-	Violeta sollte auch in ihrem letzten Kapitel noch schauen, ob jemand ein video gepostt hat von dem ganzne
-	Violeta hat Komplexe wegen ihrer Raubvogelnase (Hakennase, wie sie sie nennt)
-	Sie ist die erste und einzige, die an Bens linkem Handgelenk einen kleinen tätowierten Fuchs sieht.
-	Du- /man- passagen: Wer denkt wie? Ist Ruth im Man (NEIN)? Violeta im Du, und sie spricht sich an? Oder ist Katharina im man? Mona ist im Du, aber mit Mirjam. 
-	Durchtakten das CPR
-	Schauen, wie CPR gemacht wird heute. Zählen, nicht zählen? 

Peter. Done.
-	Informationspolitik
-	Viadukt, unter dem man Peters Vater fand: welcher wars? Irgendwo ostschweiz.
-	Die Rede sollte sich durch gesamte Peter-Perspektive hindurchziehen
-	Die Blumen, die Peter Katharina gebracht hat, sind eigentlich die Lieblingsblumen von Eva. Nicht Katharinas Lieblingsblumen. Das soll am Schluss klar werden
-	Peters Ehering ist aus Weissgold. Bei Ruth auch so beschreiben
-	Prägende Sätze für Peter:  Grosse Buben weinen nicht. Bist du eigentlich schwul? Ich bin bloss eines deiner Mädchen. Du wirst nicht so ein Versager wie dein Vater.
-	Stottern ist ein Thema
-	Das Stakkato durchziehen, wobei es am Schluss etwas abflauen darf. 
-	Ab wann hat er die Wohnung an der Brunngasse? Das einbauen bzw. klar werden mir selbst, dann ists auch im Text klar.
-	Abgleichen mit Katharina, wenn Katharina überarbeitet ist. Eventuell kann ich das im Gesamtkontext dann auch machen.
-	Überprüfen Ablauf Bundesratswahl
'''

# %%
artikel = nlp(artikel)
len(artikel.ents)
# Out:
# 138

# %%
labels = [x.label_ for x in artikel.ents]
Counter(labels)
# Out:
# Counter({'LOC': 28, 'MISC': 31, 'PER': 75, 'ORG': 4})

# %%
items = [x.text for x in artikel.ents]
Counter(items).most_common(8)
# Out:
# [('Mona', 9),
#  ('Violeta', 9),
#  ('Katharina', 9),
#  ('Ruth', 9),
#  ('Fuchs', 6),
#  ('katharina', 4),
#  ('Done', 4),
#  ('Peter', 3)]

# %%
saetze = [x for x in artikel.sents]
#print(sentences[2])
saetze[19]
# Out:
# Ists genügend im Hier und Jetzt verankert, oder brauchts noch mehr Szenen von rundum?

# %%
displacy.render(artikel, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Noch zu machen</br>Allgemein:</br>1.	Runde</br>-	Tempo anschauen: Schnipsel von
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Infos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . Verankerung im Hier und Jetzt. Nicht zu lange
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vergangenheits-Passagen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .
# ...

# %%
displacy.render(nlp(str(saetze[19])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="de" id="7ff85aa6f0344821a6eaac0dec748a1c-0" class="displacy" width="1850" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Ists</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">genügend</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">im</tspan>
# ...
